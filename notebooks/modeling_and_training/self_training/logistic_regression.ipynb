# %% [markdown]
# # Modeling & Training

# %% [markdown]
# ## Logistic Regression

# %% [markdown]
# ## Outline
# - [Necessary packages](#necessary_packages)
# - [Data Loading](#data_loading)
# - [Modeling and training](#modeling_and_training)
# - [Conclusion](#conclusion)
# - [Save the best model](#save_the_best_model)

# %% [markdown]
# <div id="necessary_packages" >
#     <h3>Necessary packages</h3>
# </div>

# %%
import pandas as pd
import numpy as np
import os
from sklearn.preprocessing import StandardScaler,MaxAbsScaler,FunctionTransformer
from sklearn.feature_extraction.text import CountVectorizer,TfidfVectorizer
from sklearn.linear_model import LogisticRegression
from sklearn.decomposition import TruncatedSVD
from sklearn.model_selection import cross_validate,GridSearchCV,KFold
from sklearn.metrics import accuracy_score,f1_score,precision_score,recall_score,auc,confusion_matrix,make_scorer
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from imblearn.pipeline import Pipeline
from sklearn.pipeline import Pipeline as SKPipeline
from imblearn.over_sampling import SMOTE, ADASYN
from joblib import dump

# %% [markdown]
# <div id="data_loading" >
#     <h3>Data Loading</h3>
# </div>

# %%
path = os.path.join("..","..","data","clean_df.csv")
df = pd.read_csv(path, encoding="iso-8859-1")
df.fillna("",inplace=True)

# %%
df.columns
# Out:
# Index(['class', 'content', 'urls_count', 'digits_count',
#        'contains_currency_symbols', 'length'],
#       dtype='object')

# %% [markdown]
# <div id="modeling_and_training" >
#     <h3>Modeling and training</h3>
# </div>

# %%
X = df["content"]
y = df["class"]
X = X[y != -1]
y = y[y != -1]

# %%
params = {
    "class_weight": [
        { 0:0.05,1:0.95 },
        { 0:0.1,1:0.9},
        { 0:0.15,1:0.85 },
        { 0: 0.2,1: 0.8 },
        { 0: 0.3,1: 0.7},
        { 0: 0.35,1: 0.65},
        { 0: 0.4,1: 0.6},
        { 0: 0.45,1: 0.55},
        { 0: 0.5,1: 0.5}
    ]
}

# %%
scoring = {
    "accuracy":make_scorer(accuracy_score),
    "f1_score":make_scorer(f1_score),
    "precision":make_scorer(precision_score),
    "recall":make_scorer(recall_score)
}

# %%
models = {}

# %%
def results_to_df(results):
    _results = {}
    keys = ["mean_fit_time","mean_score_time","params","mean_test_accuracy","mean_test_recall","mean_test_precision","mean_test_f1_score"]
    for key in keys:
        _results[key] = results[key]
    return pd.DataFrame(_results)

# %%
def create_model(estimator,feature_extractor,with_svd,resampler=None):
    
    steps = [("feature_extractor",feature_extractor)]

    if with_svd:
        steps.append(("dr",TruncatedSVD(n_components=100)))
        steps.append(("scaler",StandardScaler()))
    else:
        steps.append(("scaler",MaxAbsScaler()))

    if resampler is not None:
        steps.append(("resampler",resampler))

    steps.append(("estimator",estimator))

    model = Pipeline(steps=steps)

    return model

# %%
def evaluate_cv(models,metrics,cv,X,y):

    df = []
    index = models.keys()
    columns = ["fit_time","score_time"]
    columns = columns + list(metrics.keys())
    
    for model in models.values():
        results = cross_validate(model, X, y, cv=cv,scoring=metrics)
        scores = []
        for score in results.values():
            scores.append(score.mean())
        df.append(scores)

    df = pd.DataFrame(data=df,index=index,columns=columns)
    return df

# %%
estimator = GridSearchCV(
    LogisticRegression(max_iter=200),
    param_grid=params,
    scoring=scoring,
    refit="f1_score",
    cv=KFold(n_splits=5, shuffle=True)
)

# %% [markdown]
# - Using Bag of words
# - No dimentiality reduction.
# - MaxAbsScaler
# - try different class weights to handle the problem of imbalanced data.

# %%
models["cv"] = create_model(estimator,feature_extractor=CountVectorizer(),with_svd=False)

# %%
models["cv"].fit(X, y)
# Out:
# Pipeline(steps=[('ct', CountVectorizer()), ('scaler', MaxAbsScaler()),
#                 ('estimator',
#                  GridSearchCV(cv=KFold(n_splits=5, random_state=None, shuffle=True),
#                               estimator=LogisticRegression(max_iter=200),
#                               param_grid={'class_weight': [{0: 0.05, 1: 0.95},
#                                                            {0: 0.1, 1: 0.9},
#                                                            {0: 0.15, 1: 0.85},
#                                                            {0: 0.2, 1: 0.8},
#                                                            {0: 0.3, 1: 0.7},
#                                                            {0: 0.35, 1: 0.65},
#                                                            {0: 0.4, 1: 0.6},
#                                                            {0: 0.45, 1: 0.55},
#                                                            {0: 0.5, 1: 0.5}]},
#                               refit='f1_score',
#                               scoring={'accuracy': make_scorer(accuracy_score),
#                                        'f1_score': make_scorer(f1_score),
#                                        'precision': make_scorer(precision_score),
#                                        'recall': make_scorer(recall_score)}))])

# %%
results_to_df(models["cv"]["estimator"].cv_results_)
# Out:
#    mean_fit_time  mean_score_time                                params  \
# 0       0.245881         0.025020  {'class_weight': {0: 0.05, 1: 0.95}}
# 1       0.243890         0.029362    {'class_weight': {0: 0.1, 1: 0.9}}
# 2       0.213413         0.021452  {'class_weight': {0: 0.15, 1: 0.85}}
# 3       0.207196         0.025998    {'class_weight': {0: 0.2, 1: 0.8}}
# 4       0.210212         0.017720    {'class_weight': {0: 0.3, 1: 0.7}}
# 5       0.182735         0.018266  {'class_weight': {0: 0.35, 1: 0.65}}
# 6       0.186102         0.015621    {'class_weight': {0: 0.4, 1: 0.6}}
# 7       0.189277         0.023660  {'class_weight': {0: 0.45, 1: 0.55}}
# 8       0.178100         0.019523    {'class_weight': {0: 0.5, 1: 0.5}}
#
#    mean_test_accuracy  mean_test_recall  mean_test_precision  \
# 0            0.583578          1.000000             0.408355
# 1            0.857572          0.993522             0.672054
# 2            0.947578          0.953495             0.873491
# 3            0.920880          0.810590             0.911922
# 4            0.886261          0.670723             0.926181
# 5            0.874394          0.623264             0.931013
# 6            0.863498          0.572181             0.940615
# 7            0.852607          0.528299             0.941541
# 8            0.844691          0.498075             0.949772
#
#    mean_test_f1_score
# 0            0.577508
# 1            0.797806
# 2            0.910249
# 3            0.854124
# 4            0.772284
# 5            0.740524
# 6            0.706592
# 7            0.673230
# 8            0.648507

# %% [markdown]
# - Using Bag of words
# - Using dimentiality reduction.
# - Standard Scaler.
# - try different class weights to handle the problem of imbalanced data.

# %%
models["cv_svd"] = create_model(estimator,feature_extractor=CountVectorizer(),with_svd=True)

# %%
models["cv_svd"].fit(X,y)
# Out:
# Pipeline(steps=[('feature_extractor', CountVectorizer()),
#                 ('dr', TruncatedSVD(n_components=100)),
#                 ('scaler', StandardScaler()),
#                 ('estimator',
#                  GridSearchCV(cv=KFold(n_splits=5, random_state=None, shuffle=True),
#                               estimator=LogisticRegression(max_iter=200),
#                               param_grid={'class_weight': [{0: 0.05, 1: 0.95},
#                                                            {0: 0.1, 1: 0.9},
#                                                            {0: 0.15, 1: 0.85},
#                                                            {0: 0.2, 1: 0.8},
#                                                            {0: 0.3, 1: 0.7},
#                                                            {0: 0.35, 1: 0.65},
#                                                            {0: 0.4, 1: 0.6},
#                                                            {0: 0.45, 1: 0.55},
#                                                            {0: 0.5, 1: 0.5}]},
#                               refit='f1_score',
#                               scoring={'accuracy': make_scorer(accuracy_score),
#                                        'f1_score': make_scorer(f1_score),
#                                        'precision': make_scorer(precision_score),
#                                        'recall': make_scorer(recall_score)}))])

# %%
results_to_df(models["cv_svd"]["estimator"].cv_results_)
# Out:
#    mean_fit_time  mean_score_time                                params  \
# 0       0.025452         0.019473  {'class_weight': {0: 0.05, 1: 0.95}}
# 1       0.020105         0.019231    {'class_weight': {0: 0.1, 1: 0.9}}
# 2       0.021213         0.019313  {'class_weight': {0: 0.15, 1: 0.85}}
# 3       0.021020         0.019288    {'class_weight': {0: 0.2, 1: 0.8}}
# 4       0.024733         0.026302    {'class_weight': {0: 0.3, 1: 0.7}}
# 5       0.029710         0.018962  {'class_weight': {0: 0.35, 1: 0.65}}
# 6       0.023535         0.019484    {'class_weight': {0: 0.4, 1: 0.6}}
# 7       0.021097         0.019690  {'class_weight': {0: 0.45, 1: 0.55}}
# 8       0.022458         0.019232    {'class_weight': {0: 0.5, 1: 0.5}}
#
#    mean_test_accuracy  mean_test_recall  mean_test_precision  \
# 0            0.737926          0.972737             0.525688
# 1            0.815095          0.959870             0.618650
# 2            0.854631          0.956422             0.677991
# 3            0.872428          0.950452             0.709216
# 4            0.904082          0.946285             0.771544
# 5            0.914944          0.933418             0.802623
# 6            0.924831          0.926522             0.831011
# 7            0.924821          0.906988             0.844073
# 8            0.916895          0.866529             0.850199
#
#    mean_test_f1_score
# 0            0.680223
# 1            0.748250
# 2            0.789951
# 3            0.809218
# 4            0.848066
# 5            0.861627
# 6            0.874752
# 7            0.872995
# 8            0.856479

# %% [markdown]
# - Tfidf Vectorizer.
# - no dimentiality reduction.
# - MaxAbsScaler
# - trying different weights.

# %%
models["tfidf"] = create_model(estimator,feature_extractor=TfidfVectorizer(),with_svd=False)

# %%
models["tfidf"].fit(X, y)
# Out:
# Pipeline(steps=[('feature_extractor', TfidfVectorizer()),
#                 ('scaler', MaxAbsScaler()),
#                 ('estimator',
#                  GridSearchCV(cv=KFold(n_splits=5, random_state=None, shuffle=True),
#                               estimator=LogisticRegression(max_iter=200),
#                               param_grid={'class_weight': [{0: 0.05, 1: 0.95},
#                                                            {0: 0.1, 1: 0.9},
#                                                            {0: 0.15, 1: 0.85},
#                                                            {0: 0.2, 1: 0.8},
#                                                            {0: 0.3, 1: 0.7},
#                                                            {0: 0.35, 1: 0.65},
#                                                            {0: 0.4, 1: 0.6},
#                                                            {0: 0.45, 1: 0.55},
#                                                            {0: 0.5, 1: 0.5}]},
#                               refit='f1_score',
#                               scoring={'accuracy': make_scorer(accuracy_score),
#                                        'f1_score': make_scorer(f1_score),
#                                        'precision': make_scorer(precision_score),
#                                        'recall': make_scorer(recall_score)}))])

# %%
results_to_df(models["tfidf"]["estimator"].cv_results_)
# Out:
#    mean_fit_time  mean_score_time                                params  \
# 0       0.117262         0.014064  {'class_weight': {0: 0.05, 1: 0.95}}
# 1       0.161831         0.023083    {'class_weight': {0: 0.1, 1: 0.9}}
# 2       0.138685         0.015393  {'class_weight': {0: 0.15, 1: 0.85}}
# 3       0.107142         0.012078    {'class_weight': {0: 0.2, 1: 0.8}}
# 4       0.129340         0.012852    {'class_weight': {0: 0.3, 1: 0.7}}
# 5       0.150454         0.019764  {'class_weight': {0: 0.35, 1: 0.65}}
# 6       0.171396         0.019398    {'class_weight': {0: 0.4, 1: 0.6}}
# 7       0.216722         0.024316  {'class_weight': {0: 0.45, 1: 0.55}}
# 8       0.183782         0.024394    {'class_weight': {0: 0.5, 1: 0.5}}
#
#    mean_test_accuracy  mean_test_recall  mean_test_precision  \
# 0            0.794254          1.000000             0.584330
# 1            0.900102          1.000000             0.744595
# 2            0.937682          1.000000             0.823664
# 3            0.957465          0.993506             0.875211
# 4            0.958460          0.930678             0.927432
# 5            0.943623          0.852768             0.948611
# 6            0.929776          0.783627             0.962945
# 7            0.917910          0.736676             0.967371
# 8            0.907028          0.694928             0.971160
#
#    mean_test_f1_score
# 0            0.734775
# 1            0.851157
# 2            0.901663
# 3            0.929389
# 4            0.928306
# 5            0.895701
# 6            0.861616
# 7            0.834249
# 8            0.808016

# %% [markdown]
# - Tfidf Vectorizer.
# - dimentiality reduction.
# - StandardScaler.
# - trying different weights.

# %%
models["tfidf_svd"] = create_model(estimator,feature_extractor=TfidfVectorizer(),with_svd=True)

# %%
models["tfidf_svd"].fit(X, y)
# Out:
# Pipeline(steps=[('feature_extractor', TfidfVectorizer()),
#                 ('dr', TruncatedSVD(n_components=100)),
#                 ('scaler', StandardScaler()),
#                 ('estimator',
#                  GridSearchCV(cv=KFold(n_splits=5, random_state=None, shuffle=True),
#                               estimator=LogisticRegression(max_iter=200),
#                               param_grid={'class_weight': [{0: 0.05, 1: 0.95},
#                                                            {0: 0.1, 1: 0.9},
#                                                            {0: 0.15, 1: 0.85},
#                                                            {0: 0.2, 1: 0.8},
#                                                            {0: 0.3, 1: 0.7},
#                                                            {0: 0.35, 1: 0.65},
#                                                            {0: 0.4, 1: 0.6},
#                                                            {0: 0.45, 1: 0.55},
#                                                            {0: 0.5, 1: 0.5}]},
#                               refit='f1_score',
#                               scoring={'accuracy': make_scorer(accuracy_score),
#                                        'f1_score': make_scorer(f1_score),
#                                        'precision': make_scorer(precision_score),
#                                        'recall': make_scorer(recall_score)}))])

# %%
results_to_df(models["tfidf_svd"]["estimator"].cv_results_)
# Out:
#    mean_fit_time  mean_score_time                                params  \
# 0       0.023043         0.023567  {'class_weight': {0: 0.05, 1: 0.95}}
# 1       0.030809         0.019038    {'class_weight': {0: 0.1, 1: 0.9}}
# 2       0.018907         0.019681  {'class_weight': {0: 0.15, 1: 0.85}}
# 3       0.019120         0.019286    {'class_weight': {0: 0.2, 1: 0.8}}
# 4       0.020523         0.019481    {'class_weight': {0: 0.3, 1: 0.7}}
# 5       0.019832         0.019391  {'class_weight': {0: 0.35, 1: 0.65}}
# 6       0.021851         0.019160    {'class_weight': {0: 0.4, 1: 0.6}}
# 7       0.052340         0.021453  {'class_weight': {0: 0.45, 1: 0.55}}
# 8       0.019263         0.019305    {'class_weight': {0: 0.5, 1: 0.5}}
#
#    mean_test_accuracy  mean_test_recall  mean_test_precision  \
# 0            0.894147          0.989082             0.733839
# 1            0.918870          0.986005             0.785241
# 2            0.934697          0.986005             0.821502
# 3            0.942608          0.976275             0.848451
# 4            0.956465          0.973198             0.886022
# 5            0.957450          0.965430             0.893723
# 6            0.958445          0.958926             0.901856
# 7            0.962406          0.958926             0.913469
# 8            0.960430          0.951778             0.912917
#
#    mean_test_f1_score
# 0            0.842103
# 1            0.873645
# 2            0.895516
# 3            0.906747
# 4            0.926618
# 5            0.927453
# 6            0.928751
# 7            0.935024
# 8            0.931282

# %% [markdown]
# - now we gonna try oversampling with the different preprocessing methods,here we'll use tow oversampling techniques.

# %%
_models = {}

# %%
_models["cv_smote"] = create_model(
    estimator=LogisticRegression(),
    feature_extractor=CountVectorizer(),
    with_svd=False,
    resampler=SMOTE(random_state=42)
)

# %%
_models["cv_svd_smote"] = create_model(
    estimator=LogisticRegression(),
    feature_extractor=CountVectorizer(),
    with_svd=True,
    resampler=SMOTE(random_state=42)
)

# %%
_models["tfidf_smote"] = create_model(
    estimator=LogisticRegression(),
    feature_extractor=TfidfVectorizer(),
    with_svd=False,
    resampler=SMOTE(random_state=42)
)

# %%
_models["tfidf_svd_smote"] = create_model(
    estimator=LogisticRegression(),
    feature_extractor=TfidfVectorizer(),
    with_svd=True,
    resampler=SMOTE(random_state=42)
)

# %%
_models["cv_adasyn"] = create_model(
    estimator=LogisticRegression(),
    feature_extractor=CountVectorizer(),
    with_svd=False,
    resampler=ADASYN(random_state=42)
)

# %%
_models["cv_svd_adasyn"] = create_model(
    estimator=LogisticRegression(),
    feature_extractor=CountVectorizer(),
    with_svd=True,
    resampler=ADASYN(random_state=42)
)

# %%
_models["tfidf_adasyn"] = create_model(
    estimator=LogisticRegression(),
    feature_extractor=TfidfVectorizer(),
    with_svd=False,
    resampler=ADASYN(random_state=42)
)

# %%
_models["tfidf_svd_adasyn"] = create_model(
    estimator=LogisticRegression(),
    feature_extractor=TfidfVectorizer(),
    with_svd=True,
    resampler=ADASYN(random_state=42)
)

# %%
evaluation_df = evaluate_cv(_models,scoring,cv=KFold(n_splits=5, shuffle=True),X=X, y=y)

# %%
evaluation_df
# Out:
#                   fit_time  score_time  accuracy  f1_score  precision  \
# cv_smote          0.908211    0.084846  0.923865  0.858635   0.909464
# cv_svd_smote      0.676897    0.078691  0.915920  0.866390   0.803644
# tfidf_smote       0.832528    0.076019  0.971316  0.949940   0.942993
# tfidf_svd_smote   0.629916    0.079904  0.950524  0.917192   0.883949
# cv_adasyn         1.706130    0.059784  0.941667  0.896671   0.929897
# cv_svd_adasyn     0.647888    0.081400  0.909999  0.859313   0.784390
# tfidf_adasyn      1.726189    0.065272  0.970317  0.948619   0.942408
# tfidf_svd_adasyn  0.674651    0.078251  0.955499  0.924813   0.901873
#
#                     recall
# cv_smote          0.820976
# cv_svd_smote      0.942691
# tfidf_smote       0.959118
# tfidf_svd_smote   0.953493
# cv_adasyn         0.867920
# cv_svd_adasyn     0.952489
# tfidf_adasyn      0.956119
# tfidf_svd_adasyn  0.951584

# %% [markdown]
# - choosing the best model overall

# %%
__models = {}

# %%
__models["cv"] = create_model(
    LogisticRegression(**models["cv"]["estimator"].best_params_),
    CountVectorizer(),
    with_svd=False,
    resampler=None
)

# %%
__models["cv_svd"] = create_model(
    LogisticRegression(**models["cv_svd"]["estimator"].best_params_),
    CountVectorizer(),
    with_svd=True,
    resampler=None
)

# %%
__models["tfidf"] = create_model(
    LogisticRegression(**models["tfidf"]["estimator"].best_params_),
    CountVectorizer(),
    with_svd=True,
    resampler=None
)

# %%
__models["tfidf_svd"] = create_model(
    LogisticRegression(**models["tfidf_svd"]["estimator"].best_params_),
    CountVectorizer(),
    with_svd=True,
    resampler=None
)

# %%
__models["with_oversampling"] = _models[evaluation_df.index[evaluation_df["f1_score"].argmax()]]

# %%
evaluation_df = evaluate_cv(__models,scoring,cv=KFold(n_splits=5, shuffle=True),X=X, y=y)

# %%
evaluation_df
# Out:
#                    fit_time  score_time  accuracy  f1_score  precision  \
# cv                 0.260647    0.085632  0.879325  0.743623   0.955639
# cv_svd             0.643494    0.068994  0.935687  0.892471   0.866972
# tfidf              0.632549    0.075859  0.935683  0.890865   0.862758
# tfidf_svd          0.656115    0.075086  0.935731  0.889423   0.879993
# with_oversampling  0.820617    0.078030  0.968370  0.944252   0.935572
#
#                      recall
# cv                 0.609669
# cv_svd             0.921234
# tfidf              0.923105
# tfidf_svd          0.899650
# with_oversampling  0.953707

# %% [markdown]
# <div id="conclusion" >
#     <h3>Conclusion</h3>
# </div>

# %% [markdown]
# - After trying several feature extraction and balancing techniques the best model the one with:
#     - Tfidf as its feature extraction technique.
#     - without dimentiality reduction.
#     - using oversampling with SMOTE.
#     - an f1_score of 0.94.

# %% [markdown]
# <div id="save_the_best_model" >
#     <h3>Save the best model</h3>
# </div>

# %%
dump(value=__models[evaluation_df.index[evaluation_df["f1_score"].argmax()]],filename=os.path.join("..","..","models","ssl","lr.joblib"))
# Out:
# ['../../models/ssl/lr.joblib']

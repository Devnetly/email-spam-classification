# %% [markdown]
# # Modeling & Training

# %% [markdown]
# ## Decision tree classifier

# %% [markdown]
# ## Outline
# - [Necessary packages](#necessary_packages)
# - [Data Loading](#data_loading)
# - [Modeling and training](#modeling_and_training)
# - [Conclusion](#conclusion)
# - [Save the best model](#save_the_best_model)

# %% [markdown]
# <div id="necessary_packages" >
#     <h3>Necessary packages</h3>
# </div>

# %%
import pandas as pd
import numpy as np
import os
from sklearn.preprocessing import MaxAbsScaler,FunctionTransformer,StandardScaler
from sklearn.feature_extraction.text import CountVectorizer,TfidfVectorizer
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import cross_validate,GridSearchCV,KFold,train_test_split
from sklearn.metrics import accuracy_score,f1_score,precision_score,recall_score,auc,confusion_matrix,make_scorer
from sklearn.decomposition import TruncatedSVD
from sklearn.compose import ColumnTransformer
from imblearn.pipeline import Pipeline
from imblearn.over_sampling import SMOTE
from joblib import dump

# %% [markdown]
# <div id="data_loading" >
#     <h3>Data Loading</h3>
# </div>

# %%
path = os.path.join("..","..","data","clean_df.csv")
df = pd.read_csv(path, encoding="iso-8859-1")
df.fillna("",inplace=True)

# %%
df.columns
# Out:
# Index(['class', 'content', 'urls_count', 'digits_count',
#        'contains_currency_symbols', 'length'],
#       dtype='object')

# %% [markdown]
# <div id="modeling_and_training" >
#     <h3>Modeling and training</h3>
# </div>

# %%
X = df["content"]
y = df["class"]
X = X[y != -1]
y = y[y != -1]

# %%
def results_to_df(results):
    _results = {}
    keys = ["mean_fit_time","mean_score_time","params","mean_test_accuracy","mean_test_recall","mean_test_precision","mean_test_f1_score"]
    for key in keys:
        _results[key] = results[key]
    return pd.DataFrame(_results)

# %%
scoring = {
    "accuracy":make_scorer(accuracy_score),
    "f1_score":make_scorer(f1_score),
    "precision":make_scorer(precision_score),
    "recall":make_scorer(recall_score)
}

# %%
params = {
    "estimator__min_samples_split": [2,5,10,20],
    "estimator__min_impurity_decrease":[0.0,0.005,0.01],
    "estimator__max_depth":[10,20,50,100,None]
}

# %%
def evaluate_cv(models,metrics,cv,X,y):

    df = []
    index = models.keys()
    columns = ["fit_time","score_time"]
    columns = columns + list(metrics.keys())
    
    for model in models.values():
        results = cross_validate(model, X, y, cv=cv,scoring=metrics)
        scores = []
        for score in results.values():
            scores.append(score.mean())
        df.append(scores)

    df = pd.DataFrame(data=df,index=index,columns=columns)
    return df

# %%
models = {}

# %%
models["cv_smote"] = Pipeline(steps=[
    ("cv", CountVectorizer()),
    ("grid_search", GridSearchCV(
        estimator=Pipeline(steps=[
            ("oversampler", SMOTE(random_state=48)),
            ("estimator",DecisionTreeClassifier())
        ]),
        param_grid=params,
        scoring=scoring,
        refit="f1_score",cv=KFold(n_splits=5, shuffle=True))
    )
])

# %%
models["cv_smote"].fit(X, y)
# Out:
# Pipeline(steps=[('cv', CountVectorizer()),
#                 ('grid_search',
#                  GridSearchCV(cv=KFold(n_splits=5, random_state=None, shuffle=True),
#                               estimator=Pipeline(steps=[('oversampler',
#                                                          SMOTE(random_state=48)),
#                                                         ('estimator',
#                                                          DecisionTreeClassifier())]),
#                               param_grid={'estimator__max_depth': [10, 20, 50,
#                                                                    100, None],
#                                           'estimator__min_impurity_decrease': [0.0,
#                                                                                0.005,
#                                                                                0.01],
#                                           'estimator__min_samples_split': [2, 5,
#                                                                            10,
#                                                                            20]},
#                               refit='f1_score',
#                               scoring={'accuracy': make_scorer(accuracy_score),
#                                        'f1_score': make_scorer(f1_score),
#                                        'precision': make_scorer(precision_score),
#                                        'recall': make_scorer(recall_score)}))])

# %%
results_to_df(models["cv_smote"]["grid_search"].cv_results_)
# Out:
#     mean_fit_time  mean_score_time  \
# 0        0.115828         0.009659
# 1        0.104551         0.009624
# 2        0.102307         0.009474
# 3        0.097577         0.009497
# 4        0.096489         0.009607
# 5        0.093243         0.009462
# 6        0.092459         0.009465
# 7        0.088965         0.009440
# 8        0.084552         0.009441
# 9        0.083034         0.009437
# 10       0.083066         0.009415
# 11       0.081380         0.009369
# 12       0.158378         0.009354
# 13       0.156096         0.009378
# 14       0.153989         0.009383
# 15       0.141962         0.009383
# 16       0.104718         0.009431
# 17       0.105116         0.009417
# 18       0.101880         0.009369
# 19       0.098161         0.009362
# 20       0.083174         0.009319
# 21       0.086331         0.009379
# 22       0.083373         0.009346
# 23       0.080476         0.009318
# 24       0.218541         0.009373
# 25       0.209856         0.009362
# 26       0.201942         0.009432
# 27       0.194147         0.009305
# 28       0.107930         0.009346
# 29       0.105548         0.009507
# 30       0.101751         0.009308
# 31       0.097353         0.009344
# 32       0.082417         0.009303
# 33       0.083288         0.009348
# 34       0.082109         0.010811
# 35       0.081308         0.009336
# 36       0.219266         0.009318
# 37       0.207824         0.009429
# 38       0.202495         0.009335
# 39       0.192190         0.009328
# 40       0.103486         0.009422
# 41       0.102389         0.009401
# 42       0.100489         0.009331
# 43       0.096961         0.009288
# 44       0.082011         0.009729
# 45       0.081704         0.009345
# 46       0.082519         0.009301
# 47       0.079390         0.009304
# 48       0.216125         0.009384
# 49       0.209470         0.009613
# 50       0.204764         0.009367
# 51       0.194367         0.009402
# 52       0.102628         0.009537
# 53       0.103279         0.009303
# 54       0.100705         0.009341
# 55       0.097539         0.009319
# 56       0.082692         0.009321
# 57       0.082780         0.009368
# 58       0.081951         0.009358
# 59       0.079706         0.009635
#
#                                                params  mean_test_accuracy  \
# 0   {'estimator__max_depth': 10, 'estimator__min_i...            0.886241
# 1   {'estimator__max_depth': 10, 'estimator__min_i...            0.884266
# 2   {'estimator__max_depth': 10, 'estimator__min_i...            0.892182
# 3   {'estimator__max_depth': 10, 'estimator__min_i...            0.888226
# 4   {'estimator__max_depth': 10, 'estimator__min_i...            0.885256
# 5   {'estimator__max_depth': 10, 'estimator__min_i...            0.888226
# 6   {'estimator__max_depth': 10, 'estimator__min_i...            0.886246
# 7   {'estimator__max_depth': 10, 'estimator__min_i...            0.889216
# 8   {'estimator__max_depth': 10, 'estimator__min_i...            0.868444
# 9   {'estimator__max_depth': 10, 'estimator__min_i...            0.867454
# 10  {'estimator__max_depth': 10, 'estimator__min_i...            0.867454
# 11  {'estimator__max_depth': 10, 'estimator__min_i...            0.868444
# 12  {'estimator__max_depth': 20, 'estimator__min_i...            0.900102
# 13  {'estimator__max_depth': 20, 'estimator__min_i...            0.891192
# 14  {'estimator__max_depth': 20, 'estimator__min_i...            0.895157
# 15  {'estimator__max_depth': 20, 'estimator__min_i...            0.898108
# 16  {'estimator__max_depth': 20, 'estimator__min_i...            0.883276
# 17  {'estimator__max_depth': 20, 'estimator__min_i...            0.886246
# 18  {'estimator__max_depth': 20, 'estimator__min_i...            0.883276
# 19  {'estimator__max_depth': 20, 'estimator__min_i...            0.884266
# 20  {'estimator__max_depth': 20, 'estimator__min_i...            0.868444
# 21  {'estimator__max_depth': 20, 'estimator__min_i...            0.867454
# 22  {'estimator__max_depth': 20, 'estimator__min_i...            0.868444
# 23  {'estimator__max_depth': 20, 'estimator__min_i...            0.868444
# 24  {'estimator__max_depth': 50, 'estimator__min_i...            0.897127
# 25  {'estimator__max_depth': 50, 'estimator__min_i...            0.892172
# 26  {'estimator__max_depth': 50, 'estimator__min_i...            0.895152
# 27  {'estimator__max_depth': 50, 'estimator__min_i...            0.891192
# 28  {'estimator__max_depth': 50, 'estimator__min_i...            0.887236
# 29  {'estimator__max_depth': 50, 'estimator__min_i...            0.886246
# 30  {'estimator__max_depth': 50, 'estimator__min_i...            0.884266
# 31  {'estimator__max_depth': 50, 'estimator__min_i...            0.883276
# 32  {'estimator__max_depth': 50, 'estimator__min_i...            0.867454
# 33  {'estimator__max_depth': 50, 'estimator__min_i...            0.868444
# 34  {'estimator__max_depth': 50, 'estimator__min_i...            0.867454
# 35  {'estimator__max_depth': 50, 'estimator__min_i...            0.867454
# 36  {'estimator__max_depth': 100, 'estimator__min_...            0.901068
# 37  {'estimator__max_depth': 100, 'estimator__min_...            0.891177
# 38  {'estimator__max_depth': 100, 'estimator__min_...            0.893162
# 39  {'estimator__max_depth': 100, 'estimator__min_...            0.899093
# 40  {'estimator__max_depth': 100, 'estimator__min_...            0.884266
# 41  {'estimator__max_depth': 100, 'estimator__min_...            0.885256
# 42  {'estimator__max_depth': 100, 'estimator__min_...            0.881295
# 43  {'estimator__max_depth': 100, 'estimator__min_...            0.887236
# 44  {'estimator__max_depth': 100, 'estimator__min_...            0.867454
# 45  {'estimator__max_depth': 100, 'estimator__min_...            0.867454
# 46  {'estimator__max_depth': 100, 'estimator__min_...            0.867454
# 47  {'estimator__max_depth': 100, 'estimator__min_...            0.867454
# 48  {'estimator__max_depth': None, 'estimator__min...            0.898112
# 49  {'estimator__max_depth': None, 'estimator__min...            0.894147
# 50  {'estimator__max_depth': None, 'estimator__min...            0.893177
# 51  {'estimator__max_depth': None, 'estimator__min...            0.898112
# 52  {'estimator__max_depth': None, 'estimator__min...            0.887236
# 53  {'estimator__max_depth': None, 'estimator__min...            0.888226
# 54  {'estimator__max_depth': None, 'estimator__min...            0.885256
# 55  {'estimator__max_depth': None, 'estimator__min...            0.884266
# 56  {'estimator__max_depth': None, 'estimator__min...            0.868444
# 57  {'estimator__max_depth': None, 'estimator__min...            0.868444
# 58  {'estimator__max_depth': None, 'estimator__min...            0.867454
# 59  {'estimator__max_depth': None, 'estimator__min...            0.867454
#
#     mean_test_recall  mean_test_precision  mean_test_f1_score
# 0           0.887134             0.760333            0.817330
# 1           0.886313             0.757278            0.814652
# 2           0.896662             0.770360            0.826790
# 3           0.889390             0.763715            0.820296
# 4           0.875814             0.763884            0.814272
# 5           0.876225             0.771607            0.818146
# 6           0.878891             0.764021            0.815724
# 7           0.878891             0.771886            0.819709
# 8           0.879290             0.725147            0.792586
# 9           0.875653             0.724252            0.790593
# 10          0.875653             0.724252            0.790593
# 11          0.879290             0.725147            0.792586
# 12          0.865206             0.807169            0.832114
# 13          0.858903             0.786536            0.818522
# 14          0.834126             0.811488            0.819877
# 15          0.848681             0.811046            0.826724
# 16          0.859119             0.768161            0.808489
# 17          0.854662             0.777622            0.811823
# 18          0.851287             0.770623            0.806569
# 19          0.851287             0.773392            0.808013
# 20          0.879290             0.725147            0.792586
# 21          0.875653             0.724252            0.790593
# 22          0.879290             0.725147            0.792586
# 23          0.879290             0.725147            0.792586
# 24          0.841132             0.812652            0.823894
# 25          0.826908             0.806271            0.814429
# 26          0.813397             0.824230            0.816033
# 27          0.816625             0.810984            0.811479
# 28          0.857887             0.778265            0.813834
# 29          0.862345             0.774392            0.813111
# 30          0.858560             0.770058            0.809358
# 31          0.858560             0.767290            0.807914
# 32          0.875653             0.724252            0.790593
# 33          0.879290             0.725147            0.792586
# 34          0.875653             0.724252            0.790593
# 35          0.875653             0.724252            0.790593
# 36          0.845604             0.820586            0.830619
# 37          0.810867             0.814998            0.810306
# 38          0.824747             0.813144            0.816134
# 39          0.824464             0.829279            0.824446
# 40          0.862196             0.768059            0.809902
# 41          0.854662             0.774853            0.810379
# 42          0.848210             0.767957            0.803712
# 43          0.857887             0.778265            0.813834
# 44          0.875653             0.724252            0.790593
# 45          0.875653             0.724252            0.790593
# 46          0.875653             0.724252            0.790593
# 47          0.875653             0.724252            0.790593
# 48          0.844813             0.812280            0.825386
# 49          0.827878             0.813250            0.817676
# 50          0.825762             0.809274            0.816041
# 51          0.827069             0.823481            0.823415
# 52          0.865571             0.775058            0.815156
# 53          0.865011             0.776955            0.816024
# 54          0.861934             0.771520            0.811723
# 55          0.858560             0.770058            0.809358
# 56          0.879290             0.725147            0.792586
# 57          0.879290             0.725147            0.792586
# 58          0.875653             0.724252            0.790593
# 59          0.875653             0.724252            0.790593

# %%
models["tfidf_smote"] = Pipeline(steps=[
    ("cv", TfidfVectorizer()),
    ("grid_search", GridSearchCV(
        estimator=Pipeline(steps=[
            ("oversampler", SMOTE(random_state=48)),
            ("estimator",DecisionTreeClassifier())
        ]),
        param_grid=params,
        scoring=scoring,
        refit="f1_score",cv=KFold(n_splits=5, shuffle=True))
    )
])

# %%
models["tfidf_smote"].fit(X, y)
# Out:
# Pipeline(steps=[('cv', TfidfVectorizer()),
#                 ('grid_search',
#                  GridSearchCV(cv=KFold(n_splits=5, random_state=None, shuffle=True),
#                               estimator=Pipeline(steps=[('oversampler',
#                                                          SMOTE(random_state=48)),
#                                                         ('estimator',
#                                                          DecisionTreeClassifier())]),
#                               param_grid={'estimator__max_depth': [10, 20, 50,
#                                                                    100, None],
#                                           'estimator__min_impurity_decrease': [0.0,
#                                                                                0.005,
#                                                                                0.01],
#                                           'estimator__min_samples_split': [2, 5,
#                                                                            10,
#                                                                            20]},
#                               refit='f1_score',
#                               scoring={'accuracy': make_scorer(accuracy_score),
#                                        'f1_score': make_scorer(f1_score),
#                                        'precision': make_scorer(precision_score),
#                                        'recall': make_scorer(recall_score)}))])

# %%
results_to_df(models["tfidf_smote"]["grid_search"].cv_results_)
# Out:
#     mean_fit_time  mean_score_time  \
# 0        0.771004         0.009640
# 1        0.729157         0.009367
# 2        0.734218         0.009893
# 3        0.735287         0.009541
# 4        0.736061         0.009396
# 5        0.727470         0.009366
# 6        0.729338         0.009329
# 7        0.729681         0.009410
# 8        0.725667         0.009382
# 9        0.721726         0.009356
# 10       0.722458         0.009353
# 11       0.722928         0.009405
# 12       0.881371         0.009384
# 13       0.877189         0.009375
# 14       0.877180         0.009566
# 15       0.875591         0.009445
# 16       0.787315         0.009338
# 17       0.784459         0.009338
# 18       0.784425         0.009365
# 19       0.775851         0.009342
# 20       0.725795         0.009349
# 21       0.725704         0.009332
# 22       0.724534         0.009668
# 23       0.724723         0.009350
# 24       1.054075         0.010783
# 25       1.056656         0.009388
# 26       1.055203         0.009398
# 27       1.036523         0.009350
# 28       0.779859         0.009338
# 29       0.784413         0.009349
# 30       0.781145         0.009325
# 31       0.783732         0.009329
# 32       0.725905         0.009315
# 33       0.726850         0.009361
# 34       0.727293         0.009357
# 35       0.726192         0.009695
# 36       1.042517         0.009364
# 37       1.058105         0.009495
# 38       1.047519         0.009370
# 39       1.047601         0.009367
# 40       0.784469         0.009324
# 41       0.780377         0.009377
# 42       0.780679         0.009388
# 43       0.781795         0.009430
# 44       0.736633         0.009382
# 45       0.732147         0.009330
# 46       0.736278         0.010062
# 47       0.733543         0.011014
# 48       1.054479         0.009389
# 49       1.044534         0.009334
# 50       1.054492         0.009334
# 51       1.043617         0.009396
# 52       0.780076         0.009360
# 53       0.781475         0.009341
# 54       0.778766         0.009350
# 55       0.782854         0.009364
# 56       0.722304         0.010005
# 57       0.727493         0.009386
# 58       0.727734         0.009897
# 59       0.721455         0.009381
#
#                                                params  mean_test_accuracy  \
# 0   {'estimator__max_depth': 10, 'estimator__min_i...            0.891172
# 1   {'estimator__max_depth': 10, 'estimator__min_i...            0.892167
# 2   {'estimator__max_depth': 10, 'estimator__min_i...            0.891177
# 3   {'estimator__max_depth': 10, 'estimator__min_i...            0.896127
# 4   {'estimator__max_depth': 10, 'estimator__min_i...            0.894152
# 5   {'estimator__max_depth': 10, 'estimator__min_i...            0.891182
# 6   {'estimator__max_depth': 10, 'estimator__min_i...            0.891182
# 7   {'estimator__max_depth': 10, 'estimator__min_i...            0.892167
# 8   {'estimator__max_depth': 10, 'estimator__min_i...            0.886231
# 9   {'estimator__max_depth': 10, 'estimator__min_i...            0.886231
# 10  {'estimator__max_depth': 10, 'estimator__min_i...            0.885241
# 11  {'estimator__max_depth': 10, 'estimator__min_i...            0.885241
# 12  {'estimator__max_depth': 20, 'estimator__min_i...            0.902063
# 13  {'estimator__max_depth': 20, 'estimator__min_i...            0.905033
# 14  {'estimator__max_depth': 20, 'estimator__min_i...            0.904043
# 15  {'estimator__max_depth': 20, 'estimator__min_i...            0.904038
# 16  {'estimator__max_depth': 20, 'estimator__min_i...            0.899098
# 17  {'estimator__max_depth': 20, 'estimator__min_i...            0.897117
# 18  {'estimator__max_depth': 20, 'estimator__min_i...            0.900088
# 19  {'estimator__max_depth': 20, 'estimator__min_i...            0.898103
# 20  {'estimator__max_depth': 20, 'estimator__min_i...            0.886231
# 21  {'estimator__max_depth': 20, 'estimator__min_i...            0.885241
# 22  {'estimator__max_depth': 20, 'estimator__min_i...            0.885241
# 23  {'estimator__max_depth': 20, 'estimator__min_i...            0.885241
# 24  {'estimator__max_depth': 50, 'estimator__min_i...            0.911969
# 25  {'estimator__max_depth': 50, 'estimator__min_i...            0.904038
# 26  {'estimator__max_depth': 50, 'estimator__min_i...            0.908994
# 27  {'estimator__max_depth': 50, 'estimator__min_i...            0.904053
# 28  {'estimator__max_depth': 50, 'estimator__min_i...            0.901073
# 29  {'estimator__max_depth': 50, 'estimator__min_i...            0.901078
# 30  {'estimator__max_depth': 50, 'estimator__min_i...            0.900083
# 31  {'estimator__max_depth': 50, 'estimator__min_i...            0.902063
# 32  {'estimator__max_depth': 50, 'estimator__min_i...            0.885241
# 33  {'estimator__max_depth': 50, 'estimator__min_i...            0.885241
# 34  {'estimator__max_depth': 50, 'estimator__min_i...            0.891182
# 35  {'estimator__max_depth': 50, 'estimator__min_i...            0.886231
# 36  {'estimator__max_depth': 100, 'estimator__min_...            0.898103
# 37  {'estimator__max_depth': 100, 'estimator__min_...            0.908979
# 38  {'estimator__max_depth': 100, 'estimator__min_...            0.904048
# 39  {'estimator__max_depth': 100, 'estimator__min_...            0.910964
# 40  {'estimator__max_depth': 100, 'estimator__min_...            0.900083
# 41  {'estimator__max_depth': 100, 'estimator__min_...            0.899098
# 42  {'estimator__max_depth': 100, 'estimator__min_...            0.900083
# 43  {'estimator__max_depth': 100, 'estimator__min_...            0.898103
# 44  {'estimator__max_depth': 100, 'estimator__min_...            0.886231
# 45  {'estimator__max_depth': 100, 'estimator__min_...            0.891182
# 46  {'estimator__max_depth': 100, 'estimator__min_...            0.885241
# 47  {'estimator__max_depth': 100, 'estimator__min_...            0.885241
# 48  {'estimator__max_depth': None, 'estimator__min...            0.910979
# 49  {'estimator__max_depth': None, 'estimator__min...            0.898112
# 50  {'estimator__max_depth': None, 'estimator__min...            0.903073
# 51  {'estimator__max_depth': None, 'estimator__min...            0.903063
# 52  {'estimator__max_depth': None, 'estimator__min...            0.900083
# 53  {'estimator__max_depth': None, 'estimator__min...            0.897117
# 54  {'estimator__max_depth': None, 'estimator__min...            0.899098
# 55  {'estimator__max_depth': None, 'estimator__min...            0.904043
# 56  {'estimator__max_depth': None, 'estimator__min...            0.891182
# 57  {'estimator__max_depth': None, 'estimator__min...            0.885241
# 58  {'estimator__max_depth': None, 'estimator__min...            0.886231
# 59  {'estimator__max_depth': None, 'estimator__min...            0.891182
#
#     mean_test_recall  mean_test_precision  mean_test_f1_score
# 0           0.916549             0.755453            0.828094
# 1           0.920058             0.756226            0.829984
# 2           0.916549             0.755331            0.828003
# 3           0.920058             0.764384            0.834703
# 4           0.916779             0.761688            0.831821
# 5           0.916779             0.755649            0.828306
# 6           0.916779             0.755649            0.828306
# 7           0.916779             0.757796            0.829589
# 8           0.910698             0.747403            0.820822
# 9           0.910698             0.747403            0.820822
# 10          0.910698             0.745270            0.819476
# 11          0.910698             0.745270            0.819476
# 12          0.878775             0.802124            0.838139
# 13          0.891294             0.801752            0.843652
# 14          0.888024             0.801354            0.841795
# 15          0.889127             0.801872            0.842470
# 16          0.909506             0.778827            0.838730
# 17          0.909506             0.774282            0.835988
# 18          0.916779             0.777905            0.841102
# 19          0.909506             0.776489            0.837290
# 20          0.910698             0.747403            0.820822
# 21          0.910698             0.745270            0.819476
# 22          0.910698             0.745270            0.819476
# 23          0.910698             0.745270            0.819476
# 24          0.886985             0.823712            0.853496
# 25          0.875011             0.809907            0.840302
# 26          0.872869             0.822932            0.846850
# 27          0.877520             0.809867            0.841132
# 28          0.916779             0.780112            0.842404
# 29          0.916779             0.780164            0.842492
# 30          0.909506             0.781034            0.840031
# 31          0.916779             0.782371            0.843794
# 32          0.910698             0.745270            0.819476
# 33          0.910698             0.745270            0.819476
# 34          0.913683             0.755760            0.826992
# 35          0.910698             0.747403            0.820822
# 36          0.855926             0.805145            0.828987
# 37          0.880538             0.821960            0.848659
# 38          0.866056             0.815467            0.839029
# 39          0.901829             0.811613            0.853492
# 40          0.909506             0.781034            0.840031
# 41          0.909506             0.778827            0.838730
# 42          0.909506             0.780672            0.839682
# 43          0.909506             0.776489            0.837290
# 44          0.910698             0.747403            0.820822
# 45          0.913683             0.755760            0.826992
# 46          0.910698             0.745270            0.819476
# 47          0.910698             0.745270            0.819476
# 48          0.888970             0.818999            0.851834
# 49          0.867390             0.800406            0.831298
# 50          0.861603             0.814841            0.837090
# 51          0.870660             0.809575            0.838210
# 52          0.909506             0.781034            0.840031
# 53          0.909506             0.774282            0.835988
# 54          0.909506             0.778827            0.838730
# 55          0.916779             0.786555            0.846186
# 56          0.913683             0.755760            0.826992
# 57          0.910698             0.745270            0.819476
# 58          0.910698             0.747403            0.820822
# 59          0.913683             0.755760            0.826992

# %%
models["cv"] = Pipeline(steps=[
    ("cv", CountVectorizer()),
    ("grid_search", GridSearchCV(
        estimator=Pipeline(steps=[
            ("estimator",DecisionTreeClassifier(class_weight="balanced"))
        ]),
        param_grid=params,
        scoring=scoring,
        refit="f1_score",cv=KFold(n_splits=5, shuffle=True))
    )
])

# %%
models["cv"].fit(X, y)
# Out:
# Pipeline(steps=[('cv', CountVectorizer()),
#                 ('grid_search',
#                  GridSearchCV(cv=KFold(n_splits=5, random_state=None, shuffle=True),
#                               estimator=Pipeline(steps=[('estimator',
#                                                          DecisionTreeClassifier(class_weight='balanced'))]),
#                               param_grid={'estimator__max_depth': [10, 20, 50,
#                                                                    100, None],
#                                           'estimator__min_impurity_decrease': [0.0,
#                                                                                0.005,
#                                                                                0.01],
#                                           'estimator__min_samples_split': [2, 5,
#                                                                            10,
#                                                                            20]},
#                               refit='f1_score',
#                               scoring={'accuracy': make_scorer(accuracy_score),
#                                        'f1_score': make_scorer(f1_score),
#                                        'precision': make_scorer(precision_score),
#                                        'recall': make_scorer(recall_score)}))])

# %%
results_to_df(models["cv"]["grid_search"].cv_results_)
# Out:
#     mean_fit_time  mean_score_time  \
# 0        0.084464         0.009316
# 1        0.084734         0.009420
# 2        0.081491         0.009298
# 3        0.078187         0.009307
# 4        0.085207         0.009638
# 5        0.083120         0.009330
# 6        0.081231         0.009335
# 7        0.075844         0.009295
# 8        0.072868         0.009339
# 9        0.073284         0.009676
# 10       0.071309         0.009293
# 11       0.067864         0.009256
# 12       0.150422         0.009298
# 13       0.140033         0.009296
# 14       0.129947         0.009316
# 15       0.125274         0.009294
# 16       0.107662         0.011166
# 17       0.103659         0.009261
# 18       0.097465         0.009324
# 19       0.096591         0.009336
# 20       0.072818         0.009298
# 21       0.072191         0.009306
# 22       0.071262         0.009336
# 23       0.068914         0.009341
# 24       0.267601         0.009355
# 25       0.251767         0.009344
# 26       0.236156         0.009308
# 27       0.226071         0.009390
# 28       0.108656         0.009269
# 29       0.105146         0.009346
# 30       0.098006         0.009301
# 31       0.092976         0.009247
# 32       0.071756         0.009229
# 33       0.072159         0.009840
# 34       0.071458         0.009276
# 35       0.068348         0.009376
# 36       0.266116         0.009325
# 37       0.249643         0.009366
# 38       0.241419         0.009818
# 39       0.236878         0.009287
# 40       0.106063         0.009227
# 41       0.104348         0.009282
# 42       0.096796         0.009313
# 43       0.094881         0.009372
# 44       0.071840         0.009311
# 45       0.071899         0.009269
# 46       0.071083         0.009278
# 47       0.068464         0.009308
# 48       0.271097         0.009333
# 49       0.257319         0.009280
# 50       0.242007         0.009276
# 51       0.231967         0.009311
# 52       0.105682         0.009299
# 53       0.105422         0.009305
# 54       0.099149         0.009268
# 55       0.093697         0.009287
# 56       0.071799         0.009203
# 57       0.072450         0.009240
# 58       0.070953         0.009238
# 59       0.067743         0.009248
#
#                                                params  mean_test_accuracy  \
# 0   {'estimator__max_depth': 10, 'estimator__min_i...            0.878301
# 1   {'estimator__max_depth': 10, 'estimator__min_i...            0.875330
# 2   {'estimator__max_depth': 10, 'estimator__min_i...            0.875326
# 3   {'estimator__max_depth': 10, 'estimator__min_i...            0.878301
# 4   {'estimator__max_depth': 10, 'estimator__min_i...            0.874340
# 5   {'estimator__max_depth': 10, 'estimator__min_i...            0.878296
# 6   {'estimator__max_depth': 10, 'estimator__min_i...            0.881252
# 7   {'estimator__max_depth': 10, 'estimator__min_i...            0.882242
# 8   {'estimator__max_depth': 10, 'estimator__min_i...            0.860503
# 9   {'estimator__max_depth': 10, 'estimator__min_i...            0.861493
# 10  {'estimator__max_depth': 10, 'estimator__min_i...            0.861493
# 11  {'estimator__max_depth': 10, 'estimator__min_i...            0.860503
# 12  {'estimator__max_depth': 20, 'estimator__min_i...            0.895113
# 13  {'estimator__max_depth': 20, 'estimator__min_i...            0.895113
# 14  {'estimator__max_depth': 20, 'estimator__min_i...            0.894123
# 15  {'estimator__max_depth': 20, 'estimator__min_i...            0.894123
# 16  {'estimator__max_depth': 20, 'estimator__min_i...            0.892143
# 17  {'estimator__max_depth': 20, 'estimator__min_i...            0.887217
# 18  {'estimator__max_depth': 20, 'estimator__min_i...            0.891153
# 19  {'estimator__max_depth': 20, 'estimator__min_i...            0.888202
# 20  {'estimator__max_depth': 20, 'estimator__min_i...            0.861493
# 21  {'estimator__max_depth': 20, 'estimator__min_i...            0.860503
# 22  {'estimator__max_depth': 20, 'estimator__min_i...            0.861493
# 23  {'estimator__max_depth': 20, 'estimator__min_i...            0.861493
# 24  {'estimator__max_depth': 50, 'estimator__min_i...            0.890192
# 25  {'estimator__max_depth': 50, 'estimator__min_i...            0.900073
# 26  {'estimator__max_depth': 50, 'estimator__min_i...            0.896113
# 27  {'estimator__max_depth': 50, 'estimator__min_i...            0.895132
# 28  {'estimator__max_depth': 50, 'estimator__min_i...            0.891153
# 29  {'estimator__max_depth': 50, 'estimator__min_i...            0.894123
# 30  {'estimator__max_depth': 50, 'estimator__min_i...            0.892143
# 31  {'estimator__max_depth': 50, 'estimator__min_i...            0.892143
# 32  {'estimator__max_depth': 50, 'estimator__min_i...            0.860503
# 33  {'estimator__max_depth': 50, 'estimator__min_i...            0.861493
# 34  {'estimator__max_depth': 50, 'estimator__min_i...            0.861493
# 35  {'estimator__max_depth': 50, 'estimator__min_i...            0.860503
# 36  {'estimator__max_depth': 100, 'estimator__min_...            0.895123
# 37  {'estimator__max_depth': 100, 'estimator__min_...            0.896123
# 38  {'estimator__max_depth': 100, 'estimator__min_...            0.901063
# 39  {'estimator__max_depth': 100, 'estimator__min_...            0.888207
# 40  {'estimator__max_depth': 100, 'estimator__min_...            0.894123
# 41  {'estimator__max_depth': 100, 'estimator__min_...            0.888202
# 42  {'estimator__max_depth': 100, 'estimator__min_...            0.893128
# 43  {'estimator__max_depth': 100, 'estimator__min_...            0.893128
# 44  {'estimator__max_depth': 100, 'estimator__min_...            0.861493
# 45  {'estimator__max_depth': 100, 'estimator__min_...            0.861493
# 46  {'estimator__max_depth': 100, 'estimator__min_...            0.860503
# 47  {'estimator__max_depth': 100, 'estimator__min_...            0.861493
# 48  {'estimator__max_depth': None, 'estimator__min...            0.894157
# 49  {'estimator__max_depth': None, 'estimator__min...            0.888207
# 50  {'estimator__max_depth': None, 'estimator__min...            0.892157
# 51  {'estimator__max_depth': None, 'estimator__min...            0.886226
# 52  {'estimator__max_depth': None, 'estimator__min...            0.892143
# 53  {'estimator__max_depth': None, 'estimator__min...            0.888202
# 54  {'estimator__max_depth': None, 'estimator__min...            0.894123
# 55  {'estimator__max_depth': None, 'estimator__min...            0.888202
# 56  {'estimator__max_depth': None, 'estimator__min...            0.860503
# 57  {'estimator__max_depth': None, 'estimator__min...            0.861493
# 58  {'estimator__max_depth': None, 'estimator__min...            0.860503
# 59  {'estimator__max_depth': None, 'estimator__min...            0.860503
#
#     mean_test_recall  mean_test_precision  mean_test_f1_score
# 0           0.954787             0.716854            0.817813
# 1           0.951338             0.712790            0.813726
# 2           0.961683             0.709357            0.815447
# 3           0.951338             0.718321            0.817205
# 4           0.940994             0.714166            0.810412
# 5           0.944442             0.720703            0.815839
# 6           0.944442             0.727099            0.819622
# 7           0.947890             0.727723            0.821559
# 8           0.947890             0.686900            0.795262
# 9           0.947890             0.688343            0.796326
# 10          0.947890             0.688343            0.796326
# 11          0.947890             0.686900            0.795262
# 12          0.913163             0.767035            0.832188
# 13          0.923754             0.763511            0.834150
# 14          0.927202             0.758963            0.833322
# 15          0.923366             0.759669            0.832695
# 16          0.937422             0.750097            0.832096
# 17          0.931268             0.742715            0.825184
# 18          0.937422             0.748004            0.830804
# 19          0.931268             0.744833            0.826422
# 20          0.947890             0.688343            0.796326
# 21          0.947890             0.686900            0.795262
# 22          0.947890             0.688343            0.796326
# 23          0.947890             0.688343            0.796326
# 24          0.855865             0.786251            0.817421
# 25          0.875333             0.798181            0.833338
# 26          0.864972             0.793139            0.826366
# 27          0.880265             0.784479            0.827971
# 28          0.937422             0.748004            0.830804
# 29          0.937422             0.754597            0.834646
# 30          0.937422             0.750097            0.832096
# 31          0.937422             0.750097            0.832096
# 32          0.947890             0.686900            0.795262
# 33          0.947890             0.688343            0.796326
# 34          0.947890             0.688343            0.796326
# 35          0.947890             0.686900            0.795262
# 36          0.896657             0.774919            0.829991
# 37          0.880274             0.787351            0.829383
# 38          0.879283             0.799071            0.835391
# 39          0.861879             0.774916            0.815284
# 40          0.937422             0.754597            0.834646
# 41          0.931268             0.744833            0.826422
# 42          0.937422             0.752342            0.833393
# 43          0.937422             0.752342            0.833393
# 44          0.947890             0.688343            0.796326
# 45          0.947890             0.688343            0.796326
# 46          0.947890             0.686900            0.795262
# 47          0.947890             0.688343            0.796326
# 48          0.865575             0.786912            0.823646
# 49          0.862399             0.775802            0.815631
# 50          0.876322             0.778114            0.823100
# 51          0.858679             0.772286            0.812254
# 52          0.937422             0.750097            0.832096
# 53          0.931268             0.744833            0.826422
# 54          0.937422             0.754597            0.834646
# 55          0.931268             0.744833            0.826422
# 56          0.947890             0.686900            0.795262
# 57          0.947890             0.688343            0.796326
# 58          0.947890             0.686900            0.795262
# 59          0.947890             0.686900            0.795262

# %%
models["tfidf"] = Pipeline(steps=[
    ("cv", TfidfVectorizer()),
    ("grid_search", GridSearchCV(
        estimator=Pipeline(steps=[
            ("estimator",DecisionTreeClassifier(class_weight="balanced"))
        ]),
        param_grid=params,
        scoring=scoring,
        refit="f1_score",cv=KFold(n_splits=5, shuffle=True))
    )
])

# %%
models["tfidf"].fit(X, y)
# Out:
# Pipeline(steps=[('cv', TfidfVectorizer()),
#                 ('grid_search',
#                  GridSearchCV(cv=KFold(n_splits=5, random_state=None, shuffle=True),
#                               estimator=Pipeline(steps=[('estimator',
#                                                          DecisionTreeClassifier(class_weight='balanced'))]),
#                               param_grid={'estimator__max_depth': [10, 20, 50,
#                                                                    100, None],
#                                           'estimator__min_impurity_decrease': [0.0,
#                                                                                0.005,
#                                                                                0.01],
#                                           'estimator__min_samples_split': [2, 5,
#                                                                            10,
#                                                                            20]},
#                               refit='f1_score',
#                               scoring={'accuracy': make_scorer(accuracy_score),
#                                        'f1_score': make_scorer(f1_score),
#                                        'precision': make_scorer(precision_score),
#                                        'recall': make_scorer(recall_score)}))])

# %%
results_to_df(models["tfidf"]["grid_search"].cv_results_)
# Out:
#     mean_fit_time  mean_score_time  \
# 0        0.116225         0.009355
# 1        0.114933         0.009536
# 2        0.110143         0.009284
# 3        0.105295         0.009302
# 4        0.113058         0.009303
# 5        0.113090         0.009314
# 6        0.108373         0.009315
# 7        0.106605         0.009685
# 8        0.103002         0.009336
# 9        0.104577         0.009373
# 10       0.103367         0.009354
# 11       0.095082         0.009343
# 12       0.195247         0.009325
# 13       0.184830         0.009394
# 14       0.169520         0.009321
# 15       0.164357         0.009427
# 16       0.146810         0.009289
# 17       0.142725         0.009733
# 18       0.134339         0.009272
# 19       0.130338         0.009720
# 20       0.105382         0.009370
# 21       0.105702         0.009716
# 22       0.102577         0.009268
# 23       0.095137         0.009259
# 24       0.262848         0.009284
# 25       0.253939         0.009295
# 26       0.245113         0.009357
# 27       0.236648         0.009324
# 28       0.146385         0.009246
# 29       0.142884         0.009261
# 30       0.134672         0.009393
# 31       0.125359         0.009259
# 32       0.103259         0.009241
# 33       0.105165         0.009338
# 34       0.103767         0.009235
# 35       0.097337         0.009315
# 36       0.286062         0.009307
# 37       0.270452         0.009296
# 38       0.254291         0.009315
# 39       0.250314         0.009250
# 40       0.149049         0.009305
# 41       0.147135         0.009290
# 42       0.138129         0.009278
# 43       0.133944         0.009809
# 44       0.105702         0.009328
# 45       0.109059         0.009280
# 46       0.103293         0.009331
# 47       0.095170         0.009241
# 48       0.265330         0.009281
# 49       0.251657         0.009288
# 50       0.247086         0.009327
# 51       0.238654         0.009474
# 52       0.145070         0.009397
# 53       0.141526         0.009793
# 54       0.133297         0.009565
# 55       0.128427         0.009493
# 56       0.104489         0.009327
# 57       0.102809         0.009732
# 58       0.101003         0.009583
# 59       0.094893         0.009238
#
#                                                params  mean_test_accuracy  \
# 0   {'estimator__max_depth': 10, 'estimator__min_i...            0.892177
# 1   {'estimator__max_depth': 10, 'estimator__min_i...            0.887236
# 2   {'estimator__max_depth': 10, 'estimator__min_i...            0.888221
# 3   {'estimator__max_depth': 10, 'estimator__min_i...            0.889206
# 4   {'estimator__max_depth': 10, 'estimator__min_i...            0.890201
# 5   {'estimator__max_depth': 10, 'estimator__min_i...            0.891196
# 6   {'estimator__max_depth': 10, 'estimator__min_i...            0.881295
# 7   {'estimator__max_depth': 10, 'estimator__min_i...            0.889211
# 8   {'estimator__max_depth': 10, 'estimator__min_i...            0.880305
# 9   {'estimator__max_depth': 10, 'estimator__min_i...            0.882286
# 10  {'estimator__max_depth': 10, 'estimator__min_i...            0.882286
# 11  {'estimator__max_depth': 10, 'estimator__min_i...            0.880305
# 12  {'estimator__max_depth': 20, 'estimator__min_i...            0.896142
# 13  {'estimator__max_depth': 20, 'estimator__min_i...            0.898117
# 14  {'estimator__max_depth': 20, 'estimator__min_i...            0.901083
# 15  {'estimator__max_depth': 20, 'estimator__min_i...            0.892167
# 16  {'estimator__max_depth': 20, 'estimator__min_i...            0.893167
# 17  {'estimator__max_depth': 20, 'estimator__min_i...            0.891192
# 18  {'estimator__max_depth': 20, 'estimator__min_i...            0.902063
# 19  {'estimator__max_depth': 20, 'estimator__min_i...            0.887231
# 20  {'estimator__max_depth': 20, 'estimator__min_i...            0.881295
# 21  {'estimator__max_depth': 20, 'estimator__min_i...            0.884266
# 22  {'estimator__max_depth': 20, 'estimator__min_i...            0.882286
# 23  {'estimator__max_depth': 20, 'estimator__min_i...            0.880305
# 24  {'estimator__max_depth': 50, 'estimator__min_i...            0.899098
# 25  {'estimator__max_depth': 50, 'estimator__min_i...            0.897113
# 26  {'estimator__max_depth': 50, 'estimator__min_i...            0.897117
# 27  {'estimator__max_depth': 50, 'estimator__min_i...            0.897113
# 28  {'estimator__max_depth': 50, 'estimator__min_i...            0.891192
# 29  {'estimator__max_depth': 50, 'estimator__min_i...            0.894152
# 30  {'estimator__max_depth': 50, 'estimator__min_i...            0.892182
# 31  {'estimator__max_depth': 50, 'estimator__min_i...            0.890206
# 32  {'estimator__max_depth': 50, 'estimator__min_i...            0.882286
# 33  {'estimator__max_depth': 50, 'estimator__min_i...            0.880305
# 34  {'estimator__max_depth': 50, 'estimator__min_i...            0.881295
# 35  {'estimator__max_depth': 50, 'estimator__min_i...            0.882286
# 36  {'estimator__max_depth': 100, 'estimator__min_...            0.894142
# 37  {'estimator__max_depth': 100, 'estimator__min_...            0.893167
# 38  {'estimator__max_depth': 100, 'estimator__min_...            0.901063
# 39  {'estimator__max_depth': 100, 'estimator__min_...            0.902058
# 40  {'estimator__max_depth': 100, 'estimator__min_...            0.893172
# 41  {'estimator__max_depth': 100, 'estimator__min_...            0.895147
# 42  {'estimator__max_depth': 100, 'estimator__min_...            0.897113
# 43  {'estimator__max_depth': 100, 'estimator__min_...            0.892172
# 44  {'estimator__max_depth': 100, 'estimator__min_...            0.880305
# 45  {'estimator__max_depth': 100, 'estimator__min_...            0.882286
# 46  {'estimator__max_depth': 100, 'estimator__min_...            0.880305
# 47  {'estimator__max_depth': 100, 'estimator__min_...            0.880305
# 48  {'estimator__max_depth': None, 'estimator__min...            0.891182
# 49  {'estimator__max_depth': None, 'estimator__min...            0.905033
# 50  {'estimator__max_depth': None, 'estimator__min...            0.907009
# 51  {'estimator__max_depth': None, 'estimator__min...            0.904048
# 52  {'estimator__max_depth': None, 'estimator__min...            0.888221
# 53  {'estimator__max_depth': None, 'estimator__min...            0.895137
# 54  {'estimator__max_depth': None, 'estimator__min...            0.892172
# 55  {'estimator__max_depth': None, 'estimator__min...            0.894142
# 56  {'estimator__max_depth': None, 'estimator__min...            0.881295
# 57  {'estimator__max_depth': None, 'estimator__min...            0.880305
# 58  {'estimator__max_depth': None, 'estimator__min...            0.882286
# 59  {'estimator__max_depth': None, 'estimator__min...            0.880305
#
#     mean_test_recall  mean_test_precision  mean_test_f1_score
# 0           0.926700             0.755673            0.832010
# 1           0.932552             0.744497            0.826480
# 2           0.932872             0.745595            0.827832
# 3           0.925940             0.750553            0.827889
# 4           0.932992             0.750720            0.830789
# 5           0.929043             0.753018            0.830695
# 6           0.923102             0.734615            0.817564
# 7           0.926030             0.751200            0.828391
# 8           0.925655             0.733425            0.816831
# 9           0.922377             0.737792            0.818601
# 10          0.922377             0.737792            0.818601
# 11          0.925655             0.733425            0.816831
# 12          0.895138             0.777167            0.831566
# 13          0.881913             0.789261            0.832504
# 14          0.891629             0.790984            0.837678
# 15          0.871102             0.780338            0.822581
# 16          0.893200             0.772334            0.828066
# 17          0.902385             0.765054            0.826953
# 18          0.909878             0.785846            0.842732
# 19          0.889426             0.760893            0.819562
# 20          0.922377             0.736058            0.817455
# 21          0.922377             0.741671            0.821023
# 22          0.922377             0.737792            0.818601
# 23          0.925655             0.733425            0.816831
# 24          0.868284             0.799277            0.831846
# 25          0.861617             0.798361            0.828436
# 26          0.878295             0.790521            0.831232
# 27          0.865621             0.795178            0.828830
# 28          0.902440             0.765022            0.826705
# 29          0.895488             0.774951            0.829806
# 30          0.905929             0.764304            0.828594
# 31          0.902420             0.762114            0.825668
# 32          0.925655             0.737303            0.819253
# 33          0.925655             0.733425            0.816831
# 34          0.922377             0.736058            0.817455
# 35          0.922377             0.737792            0.818601
# 36          0.860771             0.791895            0.823740
# 37          0.857504             0.789089            0.821428
# 38          0.881364             0.799386            0.837116
# 39          0.874841             0.803135            0.836904
# 40          0.901980             0.769109            0.829176
# 41          0.909262             0.769735            0.833022
# 42          0.909702             0.773683            0.835786
# 43          0.903036             0.766368            0.828513
# 44          0.925655             0.733425            0.816831
# 45          0.922377             0.737792            0.818601
# 46          0.925655             0.733425            0.816831
# 47          0.925655             0.733425            0.816831
# 48          0.857913             0.783156            0.818703
# 49          0.874171             0.811462            0.840646
# 50          0.885632             0.809779            0.845686
# 51          0.864841             0.813797            0.838132
# 52          0.896357             0.759296            0.821905
# 53          0.899087             0.774718            0.831674
# 54          0.899527             0.767045            0.827654
# 55          0.906369             0.770118            0.831927
# 56          0.922377             0.736058            0.817455
# 57          0.925655             0.733425            0.816831
# 58          0.925655             0.737303            0.819253
# 59          0.925655             0.733425            0.816831

# %% [markdown]
# - Choosing the best model overall.

# %%
def get_best_params(pipeline):
    params = pipeline["grid_search"].best_params_
    result = {}
    for key in params.keys():
        result[key.split("__")[1]] = params[key]
    return result

# %%
for model in models.values():
    print(get_best_params(model))
# Out:
# {'max_depth': 20, 'min_impurity_decrease': 0.0, 'min_samples_split': 2}
# {'max_depth': 50, 'min_impurity_decrease': 0.0, 'min_samples_split': 2}
# {'max_depth': 100, 'min_impurity_decrease': 0.0, 'min_samples_split': 10}
# {'max_depth': None, 'min_impurity_decrease': 0.0, 'min_samples_split': 10}

# %%
_models = {}

# %%
_models["cv_smote"] = Pipeline(steps=[
    ("cv", CountVectorizer()),
    ("oversampler", SMOTE(random_state=48)),
    ("estimator",DecisionTreeClassifier(**get_best_params(models["cv_smote"])))
])

# %%
_models["tfidf_smote"] = Pipeline(steps=[
    ("cv", TfidfVectorizer()),
    ("oversampler", SMOTE(random_state=48)),
    ("estimator",DecisionTreeClassifier(**get_best_params(models["tfidf_smote"])))
])

# %%
_models["cv"] = Pipeline(steps=[
    ("ct", CountVectorizer()),
    ("estimator",DecisionTreeClassifier(**get_best_params(models["cv"])))
])

# %%
_models["tfidf"] = Pipeline(steps=[
    ("cv", TfidfVectorizer()),
    ("estimator",DecisionTreeClassifier(**get_best_params(models["tfidf"])))
])

# %%
evaluation_df = evaluate_cv(_models,scoring,cv=KFold(shuffle=True),X=X,y=y)

# %%
evaluation_df
# Out:
#              fit_time  score_time  accuracy  f1_score  precision    recall
# cv_smote     0.242604    0.024164  0.901097  0.836348   0.797112  0.883853
# tfidf_smote  1.131949    0.025333  0.887207  0.803059   0.801169  0.818317
# cv           0.232857    0.023859  0.900083  0.825263   0.831019  0.823231
# tfidf        0.227081    0.025194  0.876369  0.772343   0.826395  0.727991

# %% [markdown]
# <div id="conclusion" >
#     <h3>Conclusion</h3>
# </div>

# %% [markdown]
# - Bag of words (CountVectorizer) as feature extraction technique.
# - with over sampling.

# %% [markdown]
# <div id="save_the_best_model" >
#     <h3>Save the best model to the disk</h3>
# </div>

# %%
dump(value=_models[evaluation_df.index[evaluation_df["f1_score"].argmax()]],
     filename=os.path.join("..","..","models","ssl","dtree.joblib"))
# Out:
# ['../../models/ssl/dtree.joblib']

# %% [markdown]
# # Modeling & Training

# %% [markdown]
# ## KNN

# %% [markdown]
# ## Outline
# - [Necessary packages](#necessary_packages)
# - [Data Loading](#data_loading)
# - [Modeling and training](#modeling_and_training)
# - [Conclusion](#conclusion)
# - [Save the best model](#save_the_best_model)

# %% [markdown]
# <div id="necessary_packages" >
#     <h3>Necessary packages</h3>
# </div>

# %%
import pandas as pd
import numpy as np
import os
from sklearn.preprocessing import MaxAbsScaler,FunctionTransformer,StandardScaler
from sklearn.feature_extraction.text import CountVectorizer,TfidfVectorizer
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import cross_validate,GridSearchCV,KFold,train_test_split
from sklearn.metrics import accuracy_score,f1_score,precision_score,recall_score,auc,confusion_matrix,make_scorer
from sklearn.decomposition import TruncatedSVD
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from imblearn.pipeline import Pipeline
from imblearn.over_sampling import SMOTE
from joblib import dump

# %% [markdown]
# <div id="data_loading" >
#     <h3>Data Loading</h3>
# </div>

# %%
path = os.path.join("..","..","data","clean_df.csv")
df = pd.read_csv(path, encoding="iso-8859-1")
df.fillna("",inplace=True)

# %%
df.columns
# Out:
# Index(['class', 'content', 'urls_count', 'digits_count',
#        'contains_currency_symbols', 'length'],
#       dtype='object')

# %% [markdown]
# <div id="modeling_and_training" >
#     <h3>Modeling and training</h3>
# </div>

# %%
X = df["content"]
y = df["class"]
X = X[y != -1]
y = y[y != -1]

# %%
def results_to_df(results):
    _results = {}
    keys = ["mean_fit_time","mean_score_time","params","mean_test_accuracy","mean_test_recall","mean_test_precision","mean_test_f1_score"]
    for key in keys:
        _results[key] = results[key]
    return pd.DataFrame(_results)

# %%
scoring = {
    "accuracy":make_scorer(accuracy_score),
    "f1_score":make_scorer(f1_score),
    "precision":make_scorer(precision_score),
    "recall":make_scorer(recall_score)
}

# %%
params = {
    "estimator__n_neighbors": [3,5,7,9,11,13],
    "estimator__weights":["uniform","distance"],
    "estimator__p":[1,2]
}

# %%
def evaluate_cv(models,metrics,cv,X,y):

    df = []
    index = models.keys()
    columns = ["fit_time","score_time"]
    columns = columns + list(metrics.keys())
    
    for model in models.values():
        results = cross_validate(model, X, y, cv=cv,scoring=metrics)
        scores = []
        for score in results.values():
            scores.append(score.mean())
        df.append(scores)

    df = pd.DataFrame(data=df,index=index,columns=columns)
    return df

# %%
models = {}

# %%
models["knn_cv"] = Pipeline(steps=[
    ("cv", CountVectorizer()),
    ("grid_search", GridSearchCV(
        estimator=Pipeline(steps=[
            ("oversampler", SMOTE(random_state=48)),
            ("scaler",MaxAbsScaler()),
            ("estimator",KNeighborsClassifier())
        ]),
        param_grid=params,
        scoring=scoring,
        refit="f1_score",cv=KFold(n_splits=5, shuffle=True))
    )
])

# %%
models["knn_cv"].fit(X, y)
# Out:
# Pipeline(steps=[('cv', CountVectorizer()),
#                 ('grid_search',
#                  GridSearchCV(cv=KFold(n_splits=5, random_state=None, shuffle=True),
#                               estimator=Pipeline(steps=[('oversampler',
#                                                          SMOTE(random_state=48)),
#                                                         ('scaler',
#                                                          MaxAbsScaler()),
#                                                         ('estimator',
#                                                          KNeighborsClassifier())]),
#                               param_grid={'estimator__n_neighbors': [3, 5, 7, 9,
#                                                                      11, 13],
#                                           'estimator__p': [1, 2],
#                                           'estimator__weights': ['uniform',
#                                                                  'distance']},
#                               refit='f1_score',
#                               scoring={'accuracy': make_scorer(accuracy_score),
#                                        'f1_score': make_scorer(f1_score),
#                                        'precision': make_scorer(precision_score),
#                                        'recall': make_scorer(recall_score)}))])

# %%
results_to_df(models["knn_cv"]["grid_search"].cv_results_)
# Out:
#     mean_fit_time  mean_score_time  \
# 0        0.045533         0.313029
# 1        0.029085         0.138798
# 2        0.028889         0.749595
# 3        0.028884         0.756656
# 4        0.028808         0.142731
# 5        0.028858         0.137203
# 6        0.029551         0.750797
# 7        0.028760         0.743561
# 8        0.028706         0.142799
# 9        0.028816         0.137244
# 10       0.028842         0.748836
# 11       0.029035         0.742972
# 12       0.028696         0.142708
# 13       0.028729         0.137381
# 14       0.028820         0.752627
# 15       0.028775         0.742552
# 16       0.028724         0.142872
# 17       0.028749         0.137689
# 18       0.028832         0.752506
# 19       0.029382         0.741675
# 20       0.028903         0.143485
# 21       0.028758         0.137710
# 22       0.028735         0.748545
# 23       0.028834         0.748066
#
#                                                params  mean_test_accuracy  \
# 0   {'estimator__n_neighbors': 3, 'estimator__p': ...            0.492586
# 1   {'estimator__n_neighbors': 3, 'estimator__p': ...            0.511389
# 2   {'estimator__n_neighbors': 3, 'estimator__p': ...            0.591484
# 3   {'estimator__n_neighbors': 3, 'estimator__p': ...            0.601380
# 4   {'estimator__n_neighbors': 5, 'estimator__p': ...            0.465873
# 5   {'estimator__n_neighbors': 5, 'estimator__p': ...            0.486656
# 6   {'estimator__n_neighbors': 5, 'estimator__p': ...            0.541038
# 7   {'estimator__n_neighbors': 5, 'estimator__p': ...            0.546978
# 8   {'estimator__n_neighbors': 7, 'estimator__p': ...            0.451027
# 9   {'estimator__n_neighbors': 7, 'estimator__p': ...            0.466863
# 10  {'estimator__n_neighbors': 7, 'estimator__p': ...            0.508413
# 11  {'estimator__n_neighbors': 7, 'estimator__p': ...            0.512369
# 12  {'estimator__n_neighbors': 9, 'estimator__p': ...            0.436185
# 13  {'estimator__n_neighbors': 9, 'estimator__p': ...            0.451027
# 14  {'estimator__n_neighbors': 9, 'estimator__p': ...            0.492582
# 15  {'estimator__n_neighbors': 9, 'estimator__p': ...            0.494557
# 16  {'estimator__n_neighbors': 11, 'estimator__p':...            0.427279
# 17  {'estimator__n_neighbors': 11, 'estimator__p':...            0.441131
# 18  {'estimator__n_neighbors': 11, 'estimator__p':...            0.467849
# 19  {'estimator__n_neighbors': 11, 'estimator__p':...            0.475765
# 20  {'estimator__n_neighbors': 13, 'estimator__p':...            0.416388
# 21  {'estimator__n_neighbors': 13, 'estimator__p':...            0.435190
# 22  {'estimator__n_neighbors': 13, 'estimator__p':...            0.460918
# 23  {'estimator__n_neighbors': 13, 'estimator__p':...            0.469824
#
#     mean_test_recall  mean_test_precision  mean_test_f1_score
# 0           0.992904             0.359799            0.527220
# 1           0.992904             0.368559            0.536695
# 2           0.940235             0.406120            0.566687
# 3           0.940235             0.412195            0.572681
# 4           1.000000             0.348719            0.516149
# 5           1.000000             0.357750            0.526137
# 6           0.970234             0.380763            0.546004
# 7           0.970234             0.383797            0.549218
# 8           1.000000             0.342684            0.509378
# 9           1.000000             0.349099            0.516603
# 10          0.989813             0.366517            0.534213
# 11          0.989813             0.368413            0.536218
# 12          1.000000             0.336853            0.502785
# 13          1.000000             0.342607            0.509347
# 14          0.993262             0.359588            0.527184
# 15          0.993262             0.360494            0.528152
# 16          1.000000             0.333420            0.498901
# 17          1.000000             0.338707            0.504927
# 18          0.990445             0.348572            0.514656
# 19          0.990445             0.351931            0.518381
# 20          1.000000             0.329646            0.494404
# 21          1.000000             0.336545            0.502375
# 22          0.994366             0.346254            0.512471
# 23          0.994366             0.349944            0.516583

# %%
models["knn_tfidf"] = Pipeline(steps=[
    ("tfidf", TfidfVectorizer()),
    ("grid_search", GridSearchCV(
        estimator=Pipeline(steps=[
            ("oversampler", SMOTE(random_state=48)),
            ("scaler",MaxAbsScaler()),
            ("estimator",KNeighborsClassifier())
        ]),
        param_grid=params,
        scoring=scoring,
        refit="f1_score",cv=KFold(n_splits=5, shuffle=True))
    )
])

# %%
models["knn_tfidf"].fit(X, y)
# Out:
# Pipeline(steps=[('tfidf', TfidfVectorizer()),
#                 ('grid_search',
#                  GridSearchCV(cv=KFold(n_splits=5, random_state=None, shuffle=True),
#                               estimator=Pipeline(steps=[('oversampler',
#                                                          SMOTE(random_state=48)),
#                                                         ('scaler',
#                                                          MaxAbsScaler()),
#                                                         ('estimator',
#                                                          KNeighborsClassifier())]),
#                               param_grid={'estimator__n_neighbors': [3, 5, 7, 9,
#                                                                      11, 13],
#                                           'estimator__p': [1, 2],
#                                           'estimator__weights': ['uniform',
#                                                                  'distance']},
#                               refit='f1_score',
#                               scoring={'accuracy': make_scorer(accuracy_score),
#                                        'f1_score': make_scorer(f1_score),
#                                        'precision': make_scorer(precision_score),
#                                        'recall': make_scorer(recall_score)}))])

# %%
results_to_df(models["knn_tfidf"]["grid_search"].cv_results_)
# Out:
#     mean_fit_time  mean_score_time  \
# 0        0.563450         0.071266
# 1        0.565015         0.066573
# 2        0.565444         0.839705
# 3        0.619416         0.927670
# 4        0.667552         0.079979
# 5        0.570580         0.066903
# 6        0.565977         0.840972
# 7        0.564104         0.834849
# 8        0.564088         0.072924
# 9        0.564403         0.066731
# 10       0.565249         0.840480
# 11       0.565020         0.835359
# 12       0.564516         0.072831
# 13       0.564719         0.066819
# 14       0.582543         0.872735
# 15       0.643754         0.898243
# 16       0.560121         0.072418
# 17       0.563183         0.066459
# 18       0.559898         0.834314
# 19       0.561409         0.833244
# 20       0.559974         0.072175
# 21       0.563986         0.066600
# 22       0.559496         0.834662
# 23       0.561927         0.833387
#
#                                                params  mean_test_accuracy  \
# 0   {'estimator__n_neighbors': 3, 'estimator__p': ...            0.470912
# 1   {'estimator__n_neighbors': 3, 'estimator__p': ...            0.471897
# 2   {'estimator__n_neighbors': 3, 'estimator__p': ...            0.549998
# 3   {'estimator__n_neighbors': 3, 'estimator__p': ...            0.561845
# 4   {'estimator__n_neighbors': 5, 'estimator__p': ...            0.470892
# 5   {'estimator__n_neighbors': 5, 'estimator__p': ...            0.472867
# 6   {'estimator__n_neighbors': 5, 'estimator__p': ...            0.517368
# 7   {'estimator__n_neighbors': 5, 'estimator__p': ...            0.528245
# 8   {'estimator__n_neighbors': 7, 'estimator__p': ...            0.473862
# 9   {'estimator__n_neighbors': 7, 'estimator__p': ...            0.476828
# 10  {'estimator__n_neighbors': 7, 'estimator__p': ...            0.537195
# 11  {'estimator__n_neighbors': 7, 'estimator__p': ...            0.555963
# 12  {'estimator__n_neighbors': 9, 'estimator__p': ...            0.475833
# 13  {'estimator__n_neighbors': 9, 'estimator__p': ...            0.477808
# 14  {'estimator__n_neighbors': 9, 'estimator__p': ...            0.585548
# 15  {'estimator__n_neighbors': 9, 'estimator__p': ...            0.596420
# 16  {'estimator__n_neighbors': 11, 'estimator__p':...            0.494645
# 17  {'estimator__n_neighbors': 11, 'estimator__p':...            0.498600
# 18  {'estimator__n_neighbors': 11, 'estimator__p':...            0.603400
# 19  {'estimator__n_neighbors': 11, 'estimator__p':...            0.610325
# 20  {'estimator__n_neighbors': 13, 'estimator__p':...            0.487714
# 21  {'estimator__n_neighbors': 13, 'estimator__p':...            0.490684
# 22  {'estimator__n_neighbors': 13, 'estimator__p':...            0.619251
# 23  {'estimator__n_neighbors': 13, 'estimator__p':...            0.627162
#
#     mean_test_recall  mean_test_precision  mean_test_f1_score
# 0           0.803509             0.330261            0.402967
# 1           0.803509             0.330606            0.403365
# 2           0.961404             0.403822            0.559699
# 3           0.961404             0.409504            0.565734
# 4           0.803509             0.462586            0.402173
# 5           0.803509             0.463340            0.403017
# 6           0.989474             0.384363            0.549113
# 7           0.989474             0.389063            0.554235
# 8           0.810526             0.413390            0.415832
# 9           0.810526             0.414496            0.417083
# 10          1.000000             0.394322            0.561771
# 11          1.000000             0.403243            0.571163
# 12          0.807018             0.364805            0.410913
# 13          0.807018             0.365567            0.411763
# 14          0.996552             0.421777            0.588115
# 15          0.996552             0.428092            0.594375
# 16          0.800566             0.405212            0.417764
# 17          0.800566             0.406723            0.419470
# 18          1.000000             0.430618            0.598397
# 19          1.000000             0.434268            0.602082
# 20          0.819072             0.421073            0.437560
# 21          0.819072             0.422216            0.438848
# 22          0.932834             0.440532            0.590283
# 23          0.932834             0.445126            0.594746

# %%
models["knn_cv_svd"] = Pipeline(steps=[
    ("cv",CountVectorizer()),
    ("dr",TruncatedSVD(n_components=100)),
    ("grid_search", GridSearchCV(
        estimator=Pipeline(steps=[
            ("oversampler", SMOTE(random_state=48)),
            ("scaler",StandardScaler()),
            ("estimator",KNeighborsClassifier())
        ]),
        param_grid=params,
        scoring=scoring,
        refit="f1_score",cv=KFold(n_splits=5, shuffle=True))
    )
])

# %%
models["knn_cv_svd"].fit(X, y)
# Out:
# Pipeline(steps=[('cv', CountVectorizer()),
#                 ('dr', TruncatedSVD(n_components=100)),
#                 ('grid_search',
#                  GridSearchCV(cv=KFold(n_splits=5, random_state=None, shuffle=True),
#                               estimator=Pipeline(steps=[('oversampler',
#                                                          SMOTE(random_state=48)),
#                                                         ('scaler',
#                                                          StandardScaler()),
#                                                         ('estimator',
#                                                          KNeighborsClassifier())]),
#                               param_grid={'estimator__n_neighbors': [3, 5, 7, 9,
#                                                                      11, 13],
#                                           'estimator__p': [1, 2],
#                                           'estimator__weights': ['uniform',
#                                                                  'distance']},
#                               refit='f1_score',
#                               scoring={'accuracy': make_scorer(accuracy_score),
#                                        'f1_score': make_scorer(f1_score),
#                                        'precision': make_scorer(precision_score),
#                                        'recall': make_scorer(recall_score)}))])

# %%
results_to_df(models["knn_cv_svd"]["grid_search"].cv_results_)
# Out:
#     mean_fit_time  mean_score_time  \
# 0        0.018441         0.046274
# 1        0.007413         0.032406
# 2        0.007182         0.011620
# 3        0.007415         0.011960
# 4        0.007385         0.043651
# 5        0.007534         0.034371
# 6        0.009216         0.014572
# 7        0.009256         0.014769
# 8        0.009290         0.049978
# 9        0.008008         0.039946
# 10       0.007777         0.012796
# 11       0.008645         0.012383
# 12       0.008001         0.050456
# 13       0.009153         0.039018
# 14       0.012009         0.023440
# 15       0.007799         0.012429
# 16       0.008019         0.046263
# 17       0.007813         0.035359
# 18       0.007890         0.012361
# 19       0.007661         0.012801
# 20       0.008175         0.047186
# 21       0.008103         0.035833
# 22       0.008011         0.013234
# 23       0.008551         0.013771
#
#                                                params  mean_test_accuracy  \
# 0   {'estimator__n_neighbors': 3, 'estimator__p': ...            0.839760
# 1   {'estimator__n_neighbors': 3, 'estimator__p': ...            0.840745
# 2   {'estimator__n_neighbors': 3, 'estimator__p': ...            0.848671
# 3   {'estimator__n_neighbors': 3, 'estimator__p': ...            0.849656
# 4   {'estimator__n_neighbors': 5, 'estimator__p': ...            0.829864
# 5   {'estimator__n_neighbors': 5, 'estimator__p': ...            0.829864
# 6   {'estimator__n_neighbors': 5, 'estimator__p': ...            0.833819
# 7   {'estimator__n_neighbors': 5, 'estimator__p': ...            0.834805
# 8   {'estimator__n_neighbors': 7, 'estimator__p': ...            0.808135
# 9   {'estimator__n_neighbors': 7, 'estimator__p': ...            0.811101
# 10  {'estimator__n_neighbors': 7, 'estimator__p': ...            0.816037
# 11  {'estimator__n_neighbors': 7, 'estimator__p': ...            0.817027
# 12  {'estimator__n_neighbors': 9, 'estimator__p': ...            0.797239
# 13  {'estimator__n_neighbors': 9, 'estimator__p': ...            0.800205
# 14  {'estimator__n_neighbors': 9, 'estimator__p': ...            0.809125
# 15  {'estimator__n_neighbors': 9, 'estimator__p': ...            0.811096
# 16  {'estimator__n_neighbors': 11, 'estimator__p':...            0.787338
# 17  {'estimator__n_neighbors': 11, 'estimator__p':...            0.794264
# 18  {'estimator__n_neighbors': 11, 'estimator__p':...            0.794294
# 19  {'estimator__n_neighbors': 11, 'estimator__p':...            0.802205
# 20  {'estimator__n_neighbors': 13, 'estimator__p':...            0.774496
# 21  {'estimator__n_neighbors': 13, 'estimator__p':...            0.785378
# 22  {'estimator__n_neighbors': 13, 'estimator__p':...            0.780447
# 23  {'estimator__n_neighbors': 13, 'estimator__p':...            0.788363
#
#     mean_test_recall  mean_test_precision  mean_test_f1_score
# 0           0.938769             0.654975            0.770691
# 1           0.938769             0.656591            0.771789
# 2           0.940758             0.669167            0.781142
# 3           0.940758             0.670834            0.782252
# 4           0.950021             0.638679            0.762602
# 5           0.950021             0.638679            0.762602
# 6           0.947427             0.644579            0.766159
# 7           0.947427             0.646195            0.767258
# 8           0.950021             0.608939            0.740665
# 9           0.950021             0.612364            0.743391
# 10          0.944487             0.619886            0.747112
# 11          0.944487             0.621111            0.748085
# 12          0.953300             0.593389            0.730291
# 13          0.953300             0.597088            0.733115
# 14          0.958339             0.609676            0.743411
# 15          0.958339             0.612166            0.745290
# 16          0.949910             0.581717            0.720289
# 17          0.949910             0.589559            0.726515
# 18          0.958339             0.592056            0.729559
# 19          0.958339             0.600832            0.736689
# 20          0.949910             0.566147            0.708286
# 21          0.949910             0.578119            0.717913
# 22          0.958339             0.574519            0.716261
# 23          0.958339             0.583468            0.723443

# %%
models["knn_tfidf_svd"] = Pipeline(steps=[
    ("cv",TfidfVectorizer()),
    ("dr",TruncatedSVD(n_components=100)),
    ("grid_search", GridSearchCV(
        estimator=Pipeline(steps=[
            ("oversampler", SMOTE(random_state=48)),
            ("scaler",StandardScaler()),
            ("estimator",KNeighborsClassifier())
        ]),
        param_grid=params,
        scoring=scoring,
        refit="f1_score",cv=KFold(n_splits=5, shuffle=True))
    )
])

# %%
models["knn_tfidf_svd"].fit(X, y)
# Out:
# Pipeline(steps=[('cv', TfidfVectorizer()),
#                 ('dr', TruncatedSVD(n_components=100)),
#                 ('grid_search',
#                  GridSearchCV(cv=KFold(n_splits=5, random_state=None, shuffle=True),
#                               estimator=Pipeline(steps=[('oversampler',
#                                                          SMOTE(random_state=48)),
#                                                         ('scaler',
#                                                          StandardScaler()),
#                                                         ('estimator',
#                                                          KNeighborsClassifier())]),
#                               param_grid={'estimator__n_neighbors': [3, 5, 7, 9,
#                                                                      11, 13],
#                                           'estimator__p': [1, 2],
#                                           'estimator__weights': ['uniform',
#                                                                  'distance']},
#                               refit='f1_score',
#                               scoring={'accuracy': make_scorer(accuracy_score),
#                                        'f1_score': make_scorer(f1_score),
#                                        'precision': make_scorer(precision_score),
#                                        'recall': make_scorer(recall_score)}))])

# %%
results_to_df(models["knn_tfidf_svd"]["grid_search"].cv_results_)
# Out:
#     mean_fit_time  mean_score_time  \
# 0        0.014785         0.055118
# 1        0.008298         0.036473
# 2        0.007904         0.012368
# 3        0.007967         0.012515
# 4        0.008429         0.049592
# 5        0.008293         0.035342
# 6        0.007774         0.012625
# 7        0.007811         0.012143
# 8        0.007786         0.045854
# 9        0.008417         0.035813
# 10       0.008322         0.013284
# 11       0.008330         0.014500
# 12       0.008122         0.047176
# 13       0.007775         0.034806
# 14       0.008093         0.013522
# 15       0.007850         0.012927
# 16       0.007774         0.046569
# 17       0.008188         0.037485
# 18       0.008405         0.014554
# 19       0.009739         0.017083
# 20       0.009726         0.055981
# 21       0.009872         0.043113
# 22       0.009922         0.016977
# 23       0.009961         0.017224
#
#                                                params  mean_test_accuracy  \
# 0   {'estimator__n_neighbors': 3, 'estimator__p': ...            0.746818
# 1   {'estimator__n_neighbors': 3, 'estimator__p': ...            0.754729
# 2   {'estimator__n_neighbors': 3, 'estimator__p': ...            0.754699
# 3   {'estimator__n_neighbors': 3, 'estimator__p': ...            0.758650
# 4   {'estimator__n_neighbors': 5, 'estimator__p': ...            0.657796
# 5   {'estimator__n_neighbors': 5, 'estimator__p': ...            0.675604
# 6   {'estimator__n_neighbors': 5, 'estimator__p': ...            0.670673
# 7   {'estimator__n_neighbors': 5, 'estimator__p': ...            0.682539
# 8   {'estimator__n_neighbors': 7, 'estimator__p': ...            0.601390
# 9   {'estimator__n_neighbors': 7, 'estimator__p': ...            0.622158
# 10  {'estimator__n_neighbors': 7, 'estimator__p': ...            0.620212
# 11  {'estimator__n_neighbors': 7, 'estimator__p': ...            0.636039
# 12  {'estimator__n_neighbors': 9, 'estimator__p': ...            0.527196
# 13  {'estimator__n_neighbors': 9, 'estimator__p': ...            0.572687
# 14  {'estimator__n_neighbors': 9, 'estimator__p': ...            0.576681
# 15  {'estimator__n_neighbors': 9, 'estimator__p': ...            0.603395
# 16  {'estimator__n_neighbors': 11, 'estimator__p':...            0.478745
# 17  {'estimator__n_neighbors': 11, 'estimator__p':...            0.528191
# 18  {'estimator__n_neighbors': 11, 'estimator__p':...            0.521290
# 19  {'estimator__n_neighbors': 11, 'estimator__p':...            0.559874
# 20  {'estimator__n_neighbors': 13, 'estimator__p':...            0.429293
# 21  {'estimator__n_neighbors': 13, 'estimator__p':...            0.492586
# 22  {'estimator__n_neighbors': 13, 'estimator__p':...            0.479744
# 23  {'estimator__n_neighbors': 13, 'estimator__p':...            0.525235
#
#     mean_test_recall  mean_test_precision  mean_test_f1_score
# 0           0.996364             0.532543            0.693881
# 1           0.996364             0.540612            0.700672
# 2           0.996364             0.539900            0.700245
# 3           0.996364             0.543890            0.703594
# 4           1.000000             0.457766            0.627445
# 5           1.000000             0.471040            0.639787
# 6           1.000000             0.467276            0.636380
# 7           1.000000             0.476328            0.644752
# 8           1.000000             0.419460            0.590695
# 9           1.000000             0.432574            0.603560
# 10          1.000000             0.431810            0.602649
# 11          1.000000             0.442077            0.612653
# 12          1.000000             0.378530            0.548904
# 13          1.000000             0.402550            0.573764
# 14          1.000000             0.405291            0.576313
# 15          1.000000             0.420974            0.592077
# 16          1.000000             0.355960            0.524721
# 17          1.000000             0.379038            0.549428
# 18          1.000000             0.375721            0.545895
# 19          1.000000             0.395623            0.566638
# 20          1.000000             0.335324            0.502012
# 21          1.000000             0.361974            0.531339
# 22          1.000000             0.356266            0.525129
# 23          1.000000             0.377555            0.547898

# %% [markdown]
# - Choosing the best model overall.

# %%
def get_best_params(pipeline):
    params = pipeline["grid_search"].best_params_
    result = {}
    for key in params.keys():
        result[key.split("__")[1]] = params[key]
    return result

# %%
for model in models.values():
    print(get_best_params(model))
# Out:
# {'n_neighbors': 3, 'p': 2, 'weights': 'distance'}
# {'n_neighbors': 11, 'p': 2, 'weights': 'distance'}
# {'n_neighbors': 3, 'p': 2, 'weights': 'distance'}
# {'n_neighbors': 3, 'p': 2, 'weights': 'distance'}

# %%
_models = {}

# %%
_models["cv"] = Pipeline(steps=[
    ("ct", CountVectorizer()),
    ("oversampler", SMOTE(random_state=48)),
    ("scaler",MaxAbsScaler()),
    ("estimator",KNeighborsClassifier(**get_best_params(models["knn_cv"])))
])

# %%
_models["cv_svd"] = Pipeline(steps=[
    ("cv",CountVectorizer()),
    ("dr",TruncatedSVD(n_components=100)),
    ("oversampler", SMOTE(random_state=48)),
    ("scaler",StandardScaler()),
    ("estimator",KNeighborsClassifier(**get_best_params(models["knn_cv_svd"])))
])

# %%
_models["tfidf"] = Pipeline(steps=[
    ("cv", TfidfVectorizer()),
    ("oversampler", SMOTE(random_state=48)),
    ("scaler",MaxAbsScaler()),
    ("estimator",KNeighborsClassifier(**get_best_params(models["knn_tfidf"])))
])

# %%
_models["tfidf_svd"] = Pipeline(steps=[
    ("cv",TfidfVectorizer()),
    ("dr",TruncatedSVD(n_components=100)),
    ("oversampler", SMOTE(random_state=48)),
    ("scaler",StandardScaler()),
    ("estimator",KNeighborsClassifier(**get_best_params(models["knn_tfidf_svd"])))
])

# %%
evaluation_df = evaluate_cv(_models,scoring,cv=KFold(shuffle=True),X=X,y=y)

# %%
evaluation_df
# Out:
#            fit_time  score_time  accuracy  f1_score  precision    recall
# cv         0.118670    0.658512  0.607292  0.587133   0.422077  0.969131
# cv_svd     0.582305    0.080213  0.850656  0.786228   0.667042  0.959531
# tfidf      0.730144    0.848247  0.611379  0.578750   0.500622  0.905714
# tfidf_svd  0.570592    0.087240  0.614281  0.597965   0.427232  1.000000

# %% [markdown]
# <div id="conclusion" >
#     <h3>Conclusion</h3>
# </div>

# %% [markdown]
# - KNN algorithm performs poorly on this dataset.
# - Count vectorizer with svd gives the best results.

# %% [markdown]
# <div id="save_the_best_model" >
#     <h3>Save the best model to the disk</h3>
# </div>

# %%
dump(value=_models[evaluation_df.index[evaluation_df["f1_score"].argmax()]],filename=os.path.join("..","..","models","ssl","knn.joblib"))
# Out:
# ['../../models/ssl/knn.joblib']

# %% [markdown]
# # Modeling & Training

# %% [markdown]
# ## Support Vector machine

# %% [markdown]
# ## Outline
# - [Necessary packages](#necessary_packages)
# - [Data Loading](#data_loading)
# - [Modeling and training](#modeling_and_training)
# - [Conclusion](#conclusion)
# - [Save the best model](#save_the_best_model)

# %% [markdown]
# <div id="necessary_packages" >
#     <h3>Necessary packages</h3>
# </div>

# %%
import pandas as pd
import numpy as np
import os
from sklearn.preprocessing import MaxAbsScaler,FunctionTransformer,StandardScaler
from sklearn.feature_extraction.text import CountVectorizer,TfidfVectorizer
from sklearn.svm import SVC
from sklearn.model_selection import cross_validate,GridSearchCV,KFold,train_test_split
from sklearn.metrics import accuracy_score,f1_score,precision_score,recall_score,auc,confusion_matrix,make_scorer
from sklearn.decomposition import TruncatedSVD
from sklearn.compose import ColumnTransformer
from imblearn.pipeline import Pipeline
from imblearn.over_sampling import SMOTE
from joblib import dump

# %% [markdown]
# <div id="data_loading" >
#     <h3>Data Loading</h3>
# </div>

# %%
path = os.path.join("..","..","data","clean_df.csv")
df = pd.read_csv(path, encoding="iso-8859-1")
df.fillna("",inplace=True)

# %%
df.columns
# Out:
# Index(['class', 'content', 'urls_count', 'digits_count',
#        'contains_currency_symbols', 'length'],
#       dtype='object')

# %% [markdown]
# <div id="modeling_and_training" >
#     <h3>Modeling and training</h3>
# </div>

# %%
X = df["content"]
y = df["class"]
X = X[y != -1]
y = y[y != -1]

# %%
def results_to_df(results):
    _results = {}
    keys = ["mean_fit_time","mean_score_time","params","mean_test_accuracy","mean_test_recall","mean_test_precision","mean_test_f1_score"]
    for key in keys:
        _results[key] = results[key]
    return pd.DataFrame(_results)

# %%
scoring = {
    "accuracy":make_scorer(accuracy_score),
    "f1_score":make_scorer(f1_score),
    "precision":make_scorer(precision_score),
    "recall":make_scorer(recall_score)
}

# %%
params = {
    "estimator__C": [0.1,1,10,20],
    "estimator__kernel":["sigmoid","rbf","linear"],
}

# %%
def evaluate_cv(models,metrics,cv,X,y):

    df = []
    index = models.keys()
    columns = ["fit_time","score_time"]
    columns = columns + list(metrics.keys())
    
    for model in models.values():
        results = cross_validate(model, X, y, cv=cv,scoring=metrics)
        scores = []
        for score in results.values():
            scores.append(score.mean())
        df.append(scores)

    df = pd.DataFrame(data=df,index=index,columns=columns)
    return df

# %%
models = {}

# %%
models["cv"] = Pipeline(steps=[
    ("cv", CountVectorizer()),
    ("grid_search", GridSearchCV(
        estimator=Pipeline(steps=[
            ("oversampler", SMOTE(random_state=48)),
            ("scaler",MaxAbsScaler()),
            ("estimator",SVC(probability=True))
        ]),
        param_grid=params,
        scoring=scoring,
        refit="f1_score",cv=KFold(n_splits=5, shuffle=True))
    )
])

# %%
models["cv"].fit(X, y)
# Out:
# Pipeline(steps=[('cv', CountVectorizer()),
#                 ('grid_search',
#                  GridSearchCV(cv=KFold(n_splits=5, random_state=None, shuffle=True),
#                               estimator=Pipeline(steps=[('oversampler',
#                                                          SMOTE(random_state=48)),
#                                                         ('scaler',
#                                                          MaxAbsScaler()),
#                                                         ('estimator',
#                                                          SVC(probability=True))]),
#                               param_grid={'estimator__C': [0.1, 1, 10, 20],
#                                           'estimator__kernel': ['sigmoid',
#                                                                 'rbf',
#                                                                 'linear']},
#                               refit='f1_score',
#                               scoring={'accuracy': make_scorer(accuracy_score),
#                                        'f1_score': make_scorer(f1_score),
#                                        'precision': make_scorer(precision_score),
#                                        'recall': make_scorer(recall_score)}))])

# %%
results_to_df(models["cv"]["grid_search"].cv_results_)
# Out:
#     mean_fit_time  mean_score_time  \
# 0        4.820240         0.163197
# 1        4.883171         0.157122
# 2        3.273671         0.107121
# 3        3.554674         0.116493
# 4        4.221417         0.136251
# 5        2.115513         0.067412
# 6        2.223319         0.067425
# 7        3.917315         0.098734
# 8        1.751606         0.057008
# 9        1.924583         0.059185
# 10       3.764997         0.094111
# 11       1.712939         0.056231
#
#                                                params  mean_test_accuracy  \
# 0   {'estimator__C': 0.1, 'estimator__kernel': 'si...            0.533161
# 1   {'estimator__C': 0.1, 'estimator__kernel': 'rbf'}            0.451046
# 2   {'estimator__C': 0.1, 'estimator__kernel': 'li...            0.807092
# 3   {'estimator__C': 1, 'estimator__kernel': 'sigm...            0.780364
# 4     {'estimator__C': 1, 'estimator__kernel': 'rbf'}            0.738819
# 5   {'estimator__C': 1, 'estimator__kernel': 'line...            0.870424
# 6   {'estimator__C': 10, 'estimator__kernel': 'sig...            0.844711
# 7    {'estimator__C': 10, 'estimator__kernel': 'rbf'}            0.835824
# 8   {'estimator__C': 10, 'estimator__kernel': 'lin...            0.869419
# 9   {'estimator__C': 20, 'estimator__kernel': 'sig...            0.840731
# 10   {'estimator__C': 20, 'estimator__kernel': 'rbf'}            0.834829
# 11  {'estimator__C': 20, 'estimator__kernel': 'lin...            0.864469
#
#     mean_test_recall  mean_test_precision  mean_test_f1_score
# 0           0.996610             0.387259            0.554947
# 1           0.332655             0.208401            0.253910
# 2           0.914168             0.613629            0.732031
# 3           0.957658             0.575156            0.716605
# 4           1.000000             0.526001            0.687934
# 5           0.851926             0.738286            0.790024
# 6           0.925876             0.663680            0.772996
# 7           0.968763             0.641808            0.771256
# 8           0.821976             0.751189            0.783323
# 9           0.885340             0.670256            0.762625
# 10          0.961784             0.642292            0.769471
# 11          0.815625             0.742594            0.775871

# %%
models["tfidf"] = Pipeline(steps=[
    ("cv", TfidfVectorizer()),
    ("grid_search", GridSearchCV(
        estimator=Pipeline(steps=[
            ("oversampler", SMOTE(random_state=48)),
            ("scaler",MaxAbsScaler()),
            ("estimator",SVC(probability=True))
        ]),
        param_grid=params,
        scoring=scoring,
        refit="f1_score",cv=KFold(n_splits=5, shuffle=True))
    )
])

# %%
models["tfidf"].fit(X, y)
# Out:
# Pipeline(steps=[('cv', TfidfVectorizer()),
#                 ('grid_search',
#                  GridSearchCV(cv=KFold(n_splits=5, random_state=None, shuffle=True),
#                               estimator=Pipeline(steps=[('oversampler',
#                                                          SMOTE(random_state=48)),
#                                                         ('scaler',
#                                                          MaxAbsScaler()),
#                                                         ('estimator',
#                                                          SVC(probability=True))]),
#                               param_grid={'estimator__C': [0.1, 1, 10, 20],
#                                           'estimator__kernel': ['sigmoid',
#                                                                 'rbf',
#                                                                 'linear']},
#                               refit='f1_score',
#                               scoring={'accuracy': make_scorer(accuracy_score),
#                                        'f1_score': make_scorer(f1_score),
#                                        'precision': make_scorer(precision_score),
#                                        'recall': make_scorer(recall_score)}))])

# %%
results_to_df(models["tfidf"]["grid_search"].cv_results_)
# Out:
#     mean_fit_time  mean_score_time  \
# 0        6.355462         0.172640
# 1        5.411173         0.136601
# 2        3.342667         0.089281
# 3        3.419078         0.082954
# 4        5.170290         0.118506
# 5        3.281315         0.087989
# 6        2.922892         0.066823
# 7        5.870245         0.117137
# 8        3.346905         0.087654
# 9        3.000023         0.071425
# 10       5.872970         0.117426
# 11       3.353098         0.087614
#
#                                                params  mean_test_accuracy  \
# 0   {'estimator__C': 0.1, 'estimator__kernel': 'si...            0.926820
# 1   {'estimator__C': 0.1, 'estimator__kernel': 'rbf'}            0.679535
# 2   {'estimator__C': 0.1, 'estimator__kernel': 'li...            0.952509
# 3   {'estimator__C': 1, 'estimator__kernel': 'sigm...            0.962415
# 4     {'estimator__C': 1, 'estimator__kernel': 'rbf'}            0.796240
# 5   {'estimator__C': 1, 'estimator__kernel': 'line...            0.956475
# 6   {'estimator__C': 10, 'estimator__kernel': 'sig...            0.961415
# 7    {'estimator__C': 10, 'estimator__kernel': 'rbf'}            0.808111
# 8   {'estimator__C': 10, 'estimator__kernel': 'lin...            0.956475
# 9   {'estimator__C': 20, 'estimator__kernel': 'sig...            0.963396
# 10   {'estimator__C': 20, 'estimator__kernel': 'rbf'}            0.808111
# 11  {'estimator__C': 20, 'estimator__kernel': 'lin...            0.956475
#
#     mean_test_recall  mean_test_precision  mean_test_f1_score
# 0           0.954866             0.820804            0.881946
# 1           0.905886             0.470513            0.618336
# 2           0.873834             0.959101            0.914041
# 3           0.943167             0.925842            0.933938
# 4           0.956492             0.589732            0.729279
# 5           0.886058             0.959556            0.921037
# 6           0.913354             0.951755            0.931442
# 7           0.963070             0.604255            0.742233
# 8           0.886058             0.959556            0.921037
# 9           0.920022             0.952219            0.935088
# 10          0.963070             0.604255            0.742233
# 11          0.886058             0.959556            0.921037

# %%
models["cv_svd"] = Pipeline(steps=[
    ("cv",CountVectorizer()),
    ("dr",TruncatedSVD(n_components=100)),
    ("grid_search", GridSearchCV(
        estimator=Pipeline(steps=[
            ("oversampler", SMOTE(random_state=48)),
            ("scaler",StandardScaler()),
            ("estimator",SVC(probability=True))
        ]),
        param_grid=params,
        scoring=scoring,
        refit="f1_score",cv=KFold(n_splits=5, shuffle=True))
    )
])

# %%
models["cv_svd"].fit(X, y)
# Out:
# Pipeline(steps=[('cv', CountVectorizer()),
#                 ('dr', TruncatedSVD(n_components=100)),
#                 ('grid_search',
#                  GridSearchCV(cv=KFold(n_splits=5, random_state=None, shuffle=True),
#                               estimator=Pipeline(steps=[('oversampler',
#                                                          SMOTE(random_state=48)),
#                                                         ('scaler',
#                                                          StandardScaler()),
#                                                         ('estimator',
#                                                          SVC(probability=True))]),
#                               param_grid={'estimator__C': [0.1, 1, 10, 20],
#                                           'estimator__kernel': ['sigmoid',
#                                                                 'rbf',
#                                                                 'linear']},
#                               refit='f1_score',
#                               scoring={'accuracy': make_scorer(accuracy_score),
#                                        'f1_score': make_scorer(f1_score),
#                                        'precision': make_scorer(precision_score),
#                                        'recall': make_scorer(recall_score)}))])

# %%
results_to_df(models["cv_svd"]["grid_search"].cv_results_)
# Out:
#     mean_fit_time  mean_score_time  \
# 0        0.652950         0.028198
# 1        0.533853         0.032884
# 2        0.203788         0.012623
# 3        0.463042         0.021880
# 4        0.368635         0.023486
# 5        0.200874         0.010802
# 6        0.255699         0.014654
# 7        0.251455         0.017562
# 8        0.415690         0.010050
# 9        0.229454         0.013844
# 10       0.232106         0.016448
# 11       0.584248         0.009962
#
#                                                params  mean_test_accuracy  \
# 0   {'estimator__C': 0.1, 'estimator__kernel': 'si...            0.855592
# 1   {'estimator__C': 0.1, 'estimator__kernel': 'rbf'}            0.688392
# 2   {'estimator__C': 0.1, 'estimator__kernel': 'li...            0.881295
# 3   {'estimator__C': 1, 'estimator__kernel': 'sigm...            0.820982
# 4     {'estimator__C': 1, 'estimator__kernel': 'rbf'}            0.868449
# 5   {'estimator__C': 1, 'estimator__kernel': 'line...            0.910979
# 6   {'estimator__C': 10, 'estimator__kernel': 'sig...            0.835785
# 7    {'estimator__C': 10, 'estimator__kernel': 'rbf'}            0.886256
# 8   {'estimator__C': 10, 'estimator__kernel': 'lin...            0.913954
# 9   {'estimator__C': 20, 'estimator__kernel': 'sig...            0.820948
# 10   {'estimator__C': 20, 'estimator__kernel': 'rbf'}            0.899122
# 11  {'estimator__C': 20, 'estimator__kernel': 'lin...            0.910984
#
#     mean_test_recall  mean_test_precision  mean_test_f1_score
# 0           0.865021             0.704166            0.773879
# 1           0.834796             0.476849            0.606894
# 2           0.960600             0.719059            0.821779
# 3           0.944408             0.623817            0.751216
# 4           0.889088             0.719709            0.795178
# 5           0.930860             0.792864            0.855819
# 6           0.849482             0.669895            0.747360
# 7           0.863773             0.767276            0.812537
# 8           0.910549             0.810656            0.856983
# 9           0.801105             0.654791            0.720072
# 10          0.855930             0.802293            0.827868
# 11          0.888699             0.813943            0.848811

# %%
models["tfidf_svd"] = Pipeline(steps=[
    ("cv",TfidfVectorizer()),
    ("dr",TruncatedSVD(n_components=100)),
    ("grid_search", GridSearchCV(
        estimator=Pipeline(steps=[
            ("oversampler", SMOTE(random_state=48)),
            ("scaler",StandardScaler()),
            ("estimator",SVC(probability=True))
        ]),
        param_grid=params,
        scoring=scoring,
        refit="f1_score",cv=KFold(n_splits=5, shuffle=True))
    )
])

# %%
models["tfidf_svd"].fit(X, y)
# Out:
# Pipeline(steps=[('cv', TfidfVectorizer()),
#                 ('dr', TruncatedSVD(n_components=100)),
#                 ('grid_search',
#                  GridSearchCV(cv=KFold(n_splits=5, random_state=None, shuffle=True),
#                               estimator=Pipeline(steps=[('oversampler',
#                                                          SMOTE(random_state=48)),
#                                                         ('scaler',
#                                                          StandardScaler()),
#                                                         ('estimator',
#                                                          SVC(probability=True))]),
#                               param_grid={'estimator__C': [0.1, 1, 10, 20],
#                                           'estimator__kernel': ['sigmoid',
#                                                                 'rbf',
#                                                                 'linear']},
#                               refit='f1_score',
#                               scoring={'accuracy': make_scorer(accuracy_score),
#                                        'f1_score': make_scorer(f1_score),
#                                        'precision': make_scorer(precision_score),
#                                        'recall': make_scorer(recall_score)}))])

# %%
results_to_df(models["tfidf_svd"]["grid_search"].cv_results_)
# Out:
#     mean_fit_time  mean_score_time  \
# 0        0.602991         0.025603
# 1        0.424010         0.026027
# 2        0.176817         0.010661
# 3        0.320403         0.015864
# 4        0.299555         0.019203
# 5        0.301280         0.010404
# 6        0.197239         0.012456
# 7        0.260134         0.016996
# 8        0.491726         0.009656
# 9        0.195166         0.012295
# 10       0.257674         0.016886
# 11       0.452272         0.009809
#
#                                                params  mean_test_accuracy  \
# 0   {'estimator__C': 0.1, 'estimator__kernel': 'si...            0.917885
# 1   {'estimator__C': 0.1, 'estimator__kernel': 'rbf'}            0.882286
# 2   {'estimator__C': 0.1, 'estimator__kernel': 'li...            0.949539
# 3   {'estimator__C': 1, 'estimator__kernel': 'sigm...            0.909004
# 4     {'estimator__C': 1, 'estimator__kernel': 'rbf'}            0.957450
# 5   {'estimator__C': 1, 'estimator__kernel': 'line...            0.938668
# 6   {'estimator__C': 10, 'estimator__kernel': 'sig...            0.885241
# 7    {'estimator__C': 10, 'estimator__kernel': 'rbf'}            0.968336
# 8   {'estimator__C': 10, 'estimator__kernel': 'lin...            0.924826
# 9   {'estimator__C': 20, 'estimator__kernel': 'sig...            0.856538
# 10   {'estimator__C': 20, 'estimator__kernel': 'rbf'}            0.966356
# 11  {'estimator__C': 20, 'estimator__kernel': 'lin...            0.924826
#
#     mean_test_recall  mean_test_precision  mean_test_f1_score
# 0           0.983800             0.786476            0.873834
# 1           0.740128             0.835257            0.783780
# 2           0.962368             0.876803            0.917190
# 3           0.958302             0.777492            0.857534
# 4           0.956157             0.904061            0.929261
# 5           0.935125             0.864969            0.897974
# 6           0.863740             0.769855            0.812920
# 7           0.945901             0.945741            0.945738
# 8           0.897833             0.851201            0.873334
# 9           0.857633             0.713436            0.775388
# 10          0.942055             0.943363            0.942582
# 11          0.897833             0.851201            0.873334

# %% [markdown]
# - Choosing the best model overall.

# %%
def get_best_params(pipeline):
    params = pipeline["grid_search"].best_params_
    result = {}
    for key in params.keys():
        result[key.split("__")[1]] = params[key]
    return result

# %%
for model in models.values():
    print(get_best_params(model))
# Out:
# {'C': 1, 'kernel': 'linear'}
# {'C': 20, 'kernel': 'sigmoid'}
# {'C': 10, 'kernel': 'linear'}
# {'C': 10, 'kernel': 'rbf'}

# %%
_models = {}

# %%
_models["cv"] = Pipeline(steps=[
    ("cv", CountVectorizer()),
    ("ft", FunctionTransformer()),
    ("oversampler", SMOTE(random_state=48)),
    ("scaler",MaxAbsScaler()),
    ("estimator",SVC(probability=True,**get_best_params(models["cv"])))
])

# %%
_models["cv_svd"] = Pipeline(steps=[
    ("cv",CountVectorizer()),
    ("dr",TruncatedSVD(n_components=100)),
    ("oversampler", SMOTE(random_state=48)),
    ("scaler",StandardScaler()),
    ("estimator",SVC(probability=True,**get_best_params(models["cv_svd"])))
])

# %%
_models["tfidf"] = Pipeline(steps=[
    ("cv", TfidfVectorizer()),
    ("ft", FunctionTransformer()),
    ("oversampler", SMOTE(random_state=48)),
    ("scaler",MaxAbsScaler()),
    ("estimator",SVC(probability=True,**get_best_params(models["tfidf"])))
])

# %%
_models["tfidf_svd"] = Pipeline(steps=[
    ("cv",TfidfVectorizer()),
    ("dr",TruncatedSVD(n_components=100)),
    ("oversampler", SMOTE(random_state=48)),
    ("scaler",StandardScaler()),
    ("estimator",SVC(probability=True,**get_best_params(models["tfidf_svd"])))
])

# %%
evaluation_df = evaluate_cv(_models,scoring,cv=KFold(shuffle=True),X=X,y=y)

# %%
evaluation_df
# Out:
#            fit_time  score_time  accuracy  f1_score  precision    recall
# cv         2.227077    0.079038  0.860518  0.773020   0.729154  0.828816
# cv_svd     1.069855    0.028762  0.932737  0.885551   0.853240  0.921114
# tfidf      3.015046    0.079291  0.964386  0.937951   0.935885  0.941993
# tfidf_svd  0.830321    0.037185  0.926786  0.886562   0.800334  0.996552

# %% [markdown]
# <div id="conclusion" >
#     <h3>Conclusion</h3>
# </div>

# %% [markdown]
# - Tf-Idf as a feature extraction technique.
# - without dimentiality reduction.
# - f1-score of 0.94.

# %% [markdown]
# <div id="save_the_best_model" >
#     <h3>Save the best model to the disk</h3>
# </div>

# %%
dump(value=_models[evaluation_df.index[evaluation_df["f1_score"].argmax()]],filename=os.path.join("..","..","models","ssl","svm.joblib"))
# Out:
# ['../../models/ssl/svm.joblib']

# %% [markdown]
# # Modeling & Training

# %% [markdown]
# ## Logistic Regression

# %% [markdown]
# ## Outline
# - [Necessary packages](#necessary_packages)
# - [Data Loading](#data_loading)
# - [Modeling and training](#modeling_and_training)
# - [Conclusion](#conclusion)
# - [Save the best model](#save_the_best_model)

# %% [markdown]
# <div id="necessary_packages" >
#     <h3>Necessary packages</h3>
# </div>

# %%
import pandas as pd
import numpy as np
import os
from sklearn.preprocessing import StandardScaler,MaxAbsScaler,FunctionTransformer
from sklearn.feature_extraction.text import CountVectorizer,TfidfVectorizer
from sklearn.linear_model import SGDClassifier
from sklearn.decomposition import TruncatedSVD
from sklearn.model_selection import cross_validate,GridSearchCV,KFold
from sklearn.metrics import accuracy_score,f1_score,precision_score,recall_score,auc,confusion_matrix,make_scorer
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from imblearn.pipeline import Pipeline
from imblearn.over_sampling import SMOTE, ADASYN
from joblib import dump

# %% [markdown]
# <div id="data_loading" >
#     <h3>Data Loading</h3>
# </div>

# %%
path = os.path.join("..","..","data","clean_df.csv")
df = pd.read_csv(path, encoding="iso-8859-1")
df.fillna("",inplace=True)

# %%
df.columns
# Out:
# Index(['class', 'content', 'urls_count', 'digits_count',
#        'contains_currency_symbols', 'length'],
#       dtype='object')

# %% [markdown]
# <div id="modeling_and_training" >
#     <h3>Modeling and training</h3>
# </div>

# %%
X = df["content"]
y = df["class"]
X = X[y != -1]
y = y[y != -1]

# %%
params = {
    "class_weight": [
        { 0:0.05,1:0.95 },
        { 0:0.1,1:0.9},
        { 0:0.15,1:0.85 },
        { 0: 0.2,1: 0.8 },
        { 0: 0.3,1: 0.7},
        { 0: 0.35,1: 0.65},
        { 0: 0.4,1: 0.6},
        { 0: 0.45,1: 0.55},
        { 0: 0.5,1: 0.5}
    ],
    "tol": [0.001,None]
}

# %%
scoring = {
    "accuracy":make_scorer(accuracy_score),
    "f1_score":make_scorer(f1_score),
    "precision":make_scorer(precision_score),
    "recall":make_scorer(recall_score)
}

# %%
models = {}

# %%
def results_to_df(results):
    _results = {}
    keys = ["mean_fit_time","mean_score_time","params","mean_test_accuracy","mean_test_recall","mean_test_precision","mean_test_f1_score"]
    for key in keys:
        _results[key] = results[key]
    return pd.DataFrame(_results)

# %%
def create_model(estimator,feature_extractor,with_svd,resampler=None):
    
    steps = [("feature_extractor",feature_extractor)]

    if with_svd:
        steps.append(("dr",TruncatedSVD(n_components=100)))
        steps.append(("scaler",StandardScaler()))
    else:
        steps.append(("scaler",MaxAbsScaler()))

    if resampler is not None:
        steps.append(("resampler",resampler))

    steps.append(("estimator",estimator))

    model = Pipeline(steps=steps)

    return model

# %%
def evaluate_cv(models,metrics,cv,X,y):

    df = []
    index = models.keys()
    columns = ["fit_time","score_time"]
    columns = columns + list(metrics.keys())
    
    for model in models.values():
        results = cross_validate(model, X, y, cv=cv,scoring=metrics)
        scores = []
        for score in results.values():
            scores.append(score.mean())
        df.append(scores)

    df = pd.DataFrame(data=df,index=index,columns=columns)
    return df

# %%
estimator = GridSearchCV(
    SGDClassifier(max_iter=200,loss="log_loss"),
    param_grid=params,
    scoring=scoring,
    refit="f1_score",
    cv=KFold(n_splits=5, shuffle=True)
)

# %% [markdown]
# - Using Bag of words
# - No dimentiality reduction.
# - MaxAbsScaler
# - try different class weights to handle the problem of imbalanced data.

# %%
models["cv"] = create_model(estimator,feature_extractor=CountVectorizer(),with_svd=False)

# %%
models["cv"].fit(X, y)
# Out:
# Pipeline(steps=[('feature_extractor', CountVectorizer()),
#                 ('scaler', MaxAbsScaler()),
#                 ('estimator',
#                  GridSearchCV(cv=KFold(n_splits=5, random_state=None, shuffle=True),
#                               estimator=SGDClassifier(loss='log_loss',
#                                                       max_iter=200),
#                               param_grid={'class_weight': [{0: 0.05, 1: 0.95},
#                                                            {0: 0.1, 1: 0.9},
#                                                            {0: 0.15, 1: 0.85},
#                                                            {0: 0.2, 1: 0.8},
#                                                            {0: 0.3, 1: 0.7},
#                                                            {0: 0.35, 1: 0.65},
#                                                            {0: 0.4, 1: 0.6},
#                                                            {0: 0.45, 1: 0.55},
#                                                            {0: 0.5, 1: 0.5}],
#                                           'tol': [0.001, None]},
#                               refit='f1_score',
#                               scoring={'accuracy': make_scorer(accuracy_score),
#                                        'f1_score': make_scorer(f1_score),
#                                        'precision': make_scorer(precision_score),
#                                        'recall': make_scorer(recall_score)}))])

# %%
results_to_df(models["cv"]["estimator"].cv_results_)
# Out:
#     mean_fit_time  mean_score_time  \
# 0        0.012118         0.018155
# 1        0.066456         0.008495
# 2        0.005153         0.008413
# 3        0.066542         0.008465
# 4        0.005119         0.008880
# 5        0.066123         0.008470
# 6        0.004901         0.008360
# 7        0.065902         0.008451
# 8        0.004799         0.008341
# 9        0.065851         0.008390
# 10       0.005017         0.008252
# 11       0.066734         0.008368
# 12       0.004849         0.008282
# 13       0.066710         0.010143
# 14       0.006428         0.011770
# 15       0.065398         0.008328
# 16       0.004790         0.008232
# 17       0.065690         0.008313
#
#                                                params  mean_test_accuracy  \
# 0   {'class_weight': {0: 0.05, 1: 0.95}, 'tol': 0....            0.908999
# 1   {'class_weight': {0: 0.05, 1: 0.95}, 'tol': None}            0.918895
# 2    {'class_weight': {0: 0.1, 1: 0.9}, 'tol': 0.001}            0.940638
# 3     {'class_weight': {0: 0.1, 1: 0.9}, 'tol': None}            0.945579
# 4   {'class_weight': {0: 0.15, 1: 0.85}, 'tol': 0....            0.934692
# 5   {'class_weight': {0: 0.15, 1: 0.85}, 'tol': None}            0.926786
# 6    {'class_weight': {0: 0.2, 1: 0.8}, 'tol': 0.001}            0.927781
# 7     {'class_weight': {0: 0.2, 1: 0.8}, 'tol': None}            0.918870
# 8    {'class_weight': {0: 0.3, 1: 0.7}, 'tol': 0.001}            0.925806
# 9     {'class_weight': {0: 0.3, 1: 0.7}, 'tol': None}            0.909969
# 10  {'class_weight': {0: 0.35, 1: 0.65}, 'tol': 0....            0.931727
# 11  {'class_weight': {0: 0.35, 1: 0.65}, 'tol': None}            0.902053
# 12   {'class_weight': {0: 0.4, 1: 0.6}, 'tol': 0.001}            0.926796
# 13    {'class_weight': {0: 0.4, 1: 0.6}, 'tol': None}            0.892157
# 14  {'class_weight': {0: 0.45, 1: 0.55}, 'tol': 0....            0.925791
# 15  {'class_weight': {0: 0.45, 1: 0.55}, 'tol': None}            0.891172
# 16   {'class_weight': {0: 0.5, 1: 0.5}, 'tol': 0.001}            0.914915
# 17    {'class_weight': {0: 0.5, 1: 0.5}, 'tol': None}            0.886231
#
#     mean_test_recall  mean_test_precision  mean_test_f1_score
# 0           0.978300             0.767860            0.860258
# 1           0.981809             0.786519            0.873022
# 2           0.960366             0.850431            0.901559
# 3           0.920364             0.892514            0.905866
# 4           0.924654             0.859758            0.890329
# 5           0.827873             0.909199            0.865847
# 6           0.867938             0.879663            0.872207
# 7           0.783971             0.922898            0.847134
# 8           0.813901             0.920729            0.862418
# 9           0.729746             0.946217            0.823564
# 10          0.822823             0.934398            0.874160
# 11          0.701552             0.943690            0.804451
# 12          0.808071             0.930628            0.863286
# 13          0.663488             0.944855            0.779409
# 14          0.791051             0.942154            0.859382
# 15          0.659784             0.944603            0.776651
# 16          0.740703             0.950300            0.831872
# 17          0.634770             0.952062            0.761514

# %% [markdown]
# - Using Bag of words
# - Using dimentiality reduction.
# - Standard Scaler.
# - try different class weights to handle the problem of imbalanced data.

# %%
models["cv_svd"] = create_model(estimator,feature_extractor=CountVectorizer(),with_svd=True)

# %%
models["cv_svd"].fit(X,y)
# Out:
# Pipeline(steps=[('feature_extractor', CountVectorizer()),
#                 ('dr', TruncatedSVD(n_components=100)),
#                 ('scaler', StandardScaler()),
#                 ('estimator',
#                  GridSearchCV(cv=KFold(n_splits=5, random_state=None, shuffle=True),
#                               estimator=SGDClassifier(loss='log_loss',
#                                                       max_iter=200),
#                               param_grid={'class_weight': [{0: 0.05, 1: 0.95},
#                                                            {0: 0.1, 1: 0.9},
#                                                            {0: 0.15, 1: 0.85},
#                                                            {0: 0.2, 1: 0.8},
#                                                            {0: 0.3, 1: 0.7},
#                                                            {0: 0.35, 1: 0.65},
#                                                            {0: 0.4, 1: 0.6},
#                                                            {0: 0.45, 1: 0.55},
#                                                            {0: 0.5, 1: 0.5}],
#                                           'tol': [0.001, None]},
#                               refit='f1_score',
#                               scoring={'accuracy': make_scorer(accuracy_score),
#                                        'f1_score': make_scorer(f1_score),
#                                        'precision': make_scorer(precision_score),
#                                        'recall': make_scorer(recall_score)}))])

# %%
results_to_df(models["cv_svd"]["estimator"].cv_results_)
# Out:
#     mean_fit_time  mean_score_time  \
# 0        0.051056         0.023136
# 1        0.131078         0.019205
# 2        0.042059         0.019204
# 3        0.130226         0.019359
# 4        0.040819         0.019136
# 5        0.130700         0.018653
# 6        0.036818         0.019039
# 7        0.131166         0.019728
# 8        0.030558         0.018802
# 9        0.130240         0.018498
# 10       0.029354         0.018749
# 11       0.131056         0.018922
# 12       0.031733         0.018970
# 13       0.130247         0.018903
# 14       0.028475         0.018940
# 15       0.129176         0.020300
# 16       0.033166         0.018930
# 17       0.129971         0.018686
#
#                                                params  mean_test_accuracy  \
# 0   {'class_weight': {0: 0.05, 1: 0.95}, 'tol': 0....            0.865483
# 1   {'class_weight': {0: 0.05, 1: 0.95}, 'tol': None}            0.858572
# 2    {'class_weight': {0: 0.1, 1: 0.9}, 'tol': 0.001}            0.899107
# 3     {'class_weight': {0: 0.1, 1: 0.9}, 'tol': None}            0.889226
# 4   {'class_weight': {0: 0.15, 1: 0.85}, 'tol': 0....            0.910003
# 5   {'class_weight': {0: 0.15, 1: 0.85}, 'tol': None}            0.905048
# 6    {'class_weight': {0: 0.2, 1: 0.8}, 'tol': 0.001}            0.923831
# 7     {'class_weight': {0: 0.2, 1: 0.8}, 'tol': None}            0.915924
# 8    {'class_weight': {0: 0.3, 1: 0.7}, 'tol': 0.001}            0.926796
# 9     {'class_weight': {0: 0.3, 1: 0.7}, 'tol': None}            0.928771
# 10  {'class_weight': {0: 0.35, 1: 0.65}, 'tol': 0....            0.916905
# 11  {'class_weight': {0: 0.35, 1: 0.65}, 'tol': None}            0.930752
# 12   {'class_weight': {0: 0.4, 1: 0.6}, 'tol': 0.001}            0.918895
# 13    {'class_weight': {0: 0.4, 1: 0.6}, 'tol': None}            0.930752
# 14  {'class_weight': {0: 0.45, 1: 0.55}, 'tol': 0....            0.924840
# 15  {'class_weight': {0: 0.45, 1: 0.55}, 'tol': None}            0.930756
# 16   {'class_weight': {0: 0.5, 1: 0.5}, 'tol': 0.001}            0.929776
# 17    {'class_weight': {0: 0.5, 1: 0.5}, 'tol': None}            0.930756
#
#     mean_test_recall  mean_test_precision  mean_test_f1_score
# 0           0.960823             0.691303            0.803664
# 1           0.959588             0.680724            0.796021
# 2           0.955939             0.756790            0.844457
# 3           0.959588             0.735603            0.832481
# 4           0.955884             0.780866            0.859443
# 5           0.959218             0.767918            0.852775
# 6           0.959643             0.811683            0.878934
# 7           0.956141             0.794081            0.867201
# 8           0.939306             0.829043            0.879833
# 9           0.949583             0.829060            0.884522
# 10          0.925859             0.812237            0.864141
# 11          0.942601             0.837403            0.886370
# 12          0.918730             0.821154            0.865666
# 13          0.931681             0.843650            0.884865
# 14          0.901487             0.847094            0.872867
# 15          0.917645             0.852270            0.883149
# 16          0.910456             0.853388            0.880774
# 17          0.907788             0.859630            0.881950

# %% [markdown]
# - Tfidf Vectorizer.
# - no dimentiality reduction.
# - MaxAbsScaler
# - trying different weights.

# %%
models["tfidf"] = create_model(estimator,feature_extractor=TfidfVectorizer(),with_svd=False)

# %%
models["tfidf"].fit(X, y)
# Out:
# Pipeline(steps=[('feature_extractor', TfidfVectorizer()),
#                 ('scaler', MaxAbsScaler()),
#                 ('estimator',
#                  GridSearchCV(cv=KFold(n_splits=5, random_state=None, shuffle=True),
#                               estimator=SGDClassifier(loss='log_loss',
#                                                       max_iter=200),
#                               param_grid={'class_weight': [{0: 0.05, 1: 0.95},
#                                                            {0: 0.1, 1: 0.9},
#                                                            {0: 0.15, 1: 0.85},
#                                                            {0: 0.2, 1: 0.8},
#                                                            {0: 0.3, 1: 0.7},
#                                                            {0: 0.35, 1: 0.65},
#                                                            {0: 0.4, 1: 0.6},
#                                                            {0: 0.45, 1: 0.55},
#                                                            {0: 0.5, 1: 0.5}],
#                                           'tol': [0.001, None]},
#                               refit='f1_score',
#                               scoring={'accuracy': make_scorer(accuracy_score),
#                                        'f1_score': make_scorer(f1_score),
#                                        'precision': make_scorer(precision_score),
#                                        'recall': make_scorer(recall_score)}))])

# %%
results_to_df(models["tfidf"]["estimator"].cv_results_)
# Out:
#     mean_fit_time  mean_score_time  \
# 0        0.004887         0.008282
# 1        0.067051         0.008342
# 2        0.004758         0.008239
# 3        0.068265         0.008417
# 4        0.004672         0.008208
# 5        0.067120         0.008433
# 6        0.004674         0.008208
# 7        0.066224         0.008315
# 8        0.004732         0.008257
# 9        0.067617         0.009299
# 10       0.004745         0.008213
# 11       0.066035         0.008294
# 12       0.004758         0.008178
# 13       0.066307         0.008321
# 14       0.004733         0.008229
# 15       0.066121         0.008279
# 16       0.004743         0.008414
# 17       0.072175         0.009668
#
#                                                params  mean_test_accuracy  \
# 0   {'class_weight': {0: 0.05, 1: 0.95}, 'tol': 0....            0.941652
# 1   {'class_weight': {0: 0.05, 1: 0.95}, 'tol': None}            0.943618
# 2    {'class_weight': {0: 0.1, 1: 0.9}, 'tol': 0.001}            0.953514
# 3     {'class_weight': {0: 0.1, 1: 0.9}, 'tol': None}            0.962410
# 4   {'class_weight': {0: 0.15, 1: 0.85}, 'tol': 0....            0.959450
# 5   {'class_weight': {0: 0.15, 1: 0.85}, 'tol': None}            0.970326
# 6    {'class_weight': {0: 0.2, 1: 0.8}, 'tol': 0.001}            0.966371
# 7     {'class_weight': {0: 0.2, 1: 0.8}, 'tol': None}            0.970331
# 8    {'class_weight': {0: 0.3, 1: 0.7}, 'tol': 0.001}            0.968356
# 9     {'class_weight': {0: 0.3, 1: 0.7}, 'tol': None}            0.968346
# 10  {'class_weight': {0: 0.35, 1: 0.65}, 'tol': 0....            0.970331
# 11  {'class_weight': {0: 0.35, 1: 0.65}, 'tol': None}            0.965386
# 12   {'class_weight': {0: 0.4, 1: 0.6}, 'tol': 0.001}            0.972316
# 13    {'class_weight': {0: 0.4, 1: 0.6}, 'tol': None}            0.964395
# 14  {'class_weight': {0: 0.45, 1: 0.55}, 'tol': 0....            0.971326
# 15  {'class_weight': {0: 0.45, 1: 0.55}, 'tol': None}            0.960435
# 16   {'class_weight': {0: 0.5, 1: 0.5}, 'tol': 0.001}            0.969341
# 17    {'class_weight': {0: 0.5, 1: 0.5}, 'tol': None}            0.955499
#
#     mean_test_recall  mean_test_precision  mean_test_f1_score
# 0           0.996000             0.831727            0.906153
# 1           0.996000             0.836658            0.909105
# 2           0.985443             0.869411            0.923367
# 3           0.992721             0.888932            0.937735
# 4           0.982908             0.887183            0.932510
# 5           0.979651             0.920981            0.949308
# 6           0.971294             0.915273            0.942309
# 7           0.972080             0.925829            0.948231
# 8           0.968444             0.922457            0.944796
# 9           0.955796             0.934475            0.944822
# 10          0.940898             0.953979            0.946909
# 11          0.937017             0.939586            0.938218
# 12          0.950988             0.949718            0.950223
# 13          0.927220             0.946404            0.936478
# 14          0.952041             0.947172            0.949312
# 15          0.913835             0.945685            0.929278
# 16          0.930173             0.958671            0.943945
# 17          0.888027             0.950949            0.918102

# %% [markdown]
# - Tfidf Vectorizer.
# - dimentiality reduction.
# - StandardScaler.
# - trying different weights.

# %%
models["tfidf_svd"] = create_model(estimator,feature_extractor=TfidfVectorizer(),with_svd=True)

# %%
models["tfidf_svd"].fit(X, y)
# Out:
# Pipeline(steps=[('feature_extractor', TfidfVectorizer()),
#                 ('dr', TruncatedSVD(n_components=100)),
#                 ('scaler', StandardScaler()),
#                 ('estimator',
#                  GridSearchCV(cv=KFold(n_splits=5, random_state=None, shuffle=True),
#                               estimator=SGDClassifier(loss='log_loss',
#                                                       max_iter=200),
#                               param_grid={'class_weight': [{0: 0.05, 1: 0.95},
#                                                            {0: 0.1, 1: 0.9},
#                                                            {0: 0.15, 1: 0.85},
#                                                            {0: 0.2, 1: 0.8},
#                                                            {0: 0.3, 1: 0.7},
#                                                            {0: 0.35, 1: 0.65},
#                                                            {0: 0.4, 1: 0.6},
#                                                            {0: 0.45, 1: 0.55},
#                                                            {0: 0.5, 1: 0.5}],
#                                           'tol': [0.001, None]},
#                               refit='f1_score',
#                               scoring={'accuracy': make_scorer(accuracy_score),
#                                        'f1_score': make_scorer(f1_score),
#                                        'precision': make_scorer(precision_score),
#                                        'recall': make_scorer(recall_score)}))])

# %%
results_to_df(models["tfidf_svd"]["estimator"].cv_results_)
# Out:
#     mean_fit_time  mean_score_time  \
# 0        0.037372         0.019194
# 1        0.129826         0.019055
# 2        0.031984         0.019234
# 3        0.129864         0.018903
# 4        0.033301         0.019013
# 5        0.129912         0.018885
# 6        0.027750         0.019389
# 7        0.130185         0.019050
# 8        0.033103         0.019059
# 9        0.129488         0.018975
# 10       0.024608         0.019184
# 11       0.129230         0.019302
# 12       0.031374         0.020219
# 13       0.129422         0.018947
# 14       0.037313         0.019548
# 15       0.129413         0.019065
# 16       0.038834         0.019332
# 17       0.130244         0.019097
#
#                                                params  mean_test_accuracy  \
# 0   {'class_weight': {0: 0.05, 1: 0.95}, 'tol': 0....            0.941633
# 1   {'class_weight': {0: 0.05, 1: 0.95}, 'tol': None}            0.937677
# 2    {'class_weight': {0: 0.1, 1: 0.9}, 'tol': 0.001}            0.943613
# 3     {'class_weight': {0: 0.1, 1: 0.9}, 'tol': None}            0.943613
# 4   {'class_weight': {0: 0.15, 1: 0.85}, 'tol': 0....            0.944613
# 5   {'class_weight': {0: 0.15, 1: 0.85}, 'tol': None}            0.945593
# 6    {'class_weight': {0: 0.2, 1: 0.8}, 'tol': 0.001}            0.946598
# 7     {'class_weight': {0: 0.2, 1: 0.8}, 'tol': None}            0.947574
# 8    {'class_weight': {0: 0.3, 1: 0.7}, 'tol': 0.001}            0.950554
# 9     {'class_weight': {0: 0.3, 1: 0.7}, 'tol': None}            0.949563
# 10  {'class_weight': {0: 0.35, 1: 0.65}, 'tol': 0....            0.939672
# 11  {'class_weight': {0: 0.35, 1: 0.65}, 'tol': None}            0.949568
# 12   {'class_weight': {0: 0.4, 1: 0.6}, 'tol': 0.001}            0.938692
# 13    {'class_weight': {0: 0.4, 1: 0.6}, 'tol': None}            0.945618
# 14  {'class_weight': {0: 0.45, 1: 0.55}, 'tol': 0....            0.943633
# 15  {'class_weight': {0: 0.45, 1: 0.55}, 'tol': None}            0.945613
# 16   {'class_weight': {0: 0.5, 1: 0.5}, 'tol': 0.001}            0.939687
# 17    {'class_weight': {0: 0.5, 1: 0.5}, 'tol': None}            0.940662
#
#     mean_test_recall  mean_test_precision  mean_test_f1_score
# 0           0.977251             0.844374            0.905277
# 1           0.980641             0.832152            0.899307
# 2           0.962372             0.858562            0.906311
# 3           0.973861             0.851878            0.907169
# 4           0.942418             0.873606            0.905582
# 5           0.966076             0.861121            0.909252
# 6           0.945045             0.876350            0.908818
# 7           0.959727             0.870858            0.911969
# 8           0.927539             0.900912            0.913348
# 9           0.952848             0.880400            0.914397
# 10          0.907199             0.884099            0.894181
# 11          0.945063             0.885075            0.913347
# 12          0.892850             0.891994            0.892250
# 13          0.927898             0.885885            0.905756
# 14          0.907834             0.892567            0.899750
# 15          0.927683             0.886032            0.905808
# 16          0.899425             0.888531            0.892802
# 17          0.910159             0.883772            0.896330

# %% [markdown]
# - now we gonna try oversampling with the different preprocessing methods,here we'll use tow oversampling techniques.

# %%
_models = {}

# %%
_models["cv_smote"] = create_model(
    estimator=SGDClassifier(loss="log_loss"),
    feature_extractor=CountVectorizer(),
    with_svd=False,
    resampler=SMOTE(random_state=42)
)

# %%
_models["cv_svd_smote"] = create_model(
    estimator=SGDClassifier(loss="log_loss"),
    feature_extractor=CountVectorizer(),
    with_svd=True,
    resampler=SMOTE(random_state=42)
)

# %%
_models["tfidf_smote"] = create_model(
    estimator=SGDClassifier(loss="log_loss"),
    feature_extractor=TfidfVectorizer(),
    with_svd=False,
    resampler=SMOTE(random_state=42)
)

# %%
_models["tfidf_svd_smote"] = create_model(
    estimator=SGDClassifier(loss="log_loss"),
    feature_extractor=TfidfVectorizer(),
    with_svd=True,
    resampler=SMOTE(random_state=42)
)

# %%
_models["cv_adasyn"] = create_model(
    estimator=SGDClassifier(loss="log_loss"),
    feature_extractor=CountVectorizer(),
    with_svd=False,
    resampler=ADASYN(random_state=42)
)

# %%
_models["cv_svd_adasyn"] = create_model(
    estimator=SGDClassifier(loss="log_loss"),
    feature_extractor=CountVectorizer(),
    with_svd=True,
    resampler=ADASYN(random_state=42)
)

# %%
_models["tfidf_adasyn"] = create_model(
    estimator=SGDClassifier(loss="log_loss"),
    feature_extractor=TfidfVectorizer(),
    with_svd=False,
    resampler=ADASYN(random_state=42)
)

# %%
_models["tfidf_svd_adasyn"] = create_model(
    estimator=SGDClassifier(loss="log_loss"),
    feature_extractor=TfidfVectorizer(),
    with_svd=True,
    resampler=ADASYN(random_state=42)
)

# %%
evaluation_df = evaluate_cv(_models,scoring,cv=KFold(n_splits=5, shuffle=True),X=X, y=y)

# %%
evaluation_df
# Out:
#                   fit_time  score_time  accuracy  f1_score  precision  \
# cv_smote          0.689846    0.028392  0.930766  0.876901   0.891362
# cv_svd_smote      0.626957    0.058319  0.934717  0.888196   0.876796
# tfidf_smote       0.661829    0.025657  0.946583  0.904258   0.907784
# tfidf_svd_smote   0.630237    0.057573  0.940653  0.892291   0.934138
# cv_adasyn         1.583080    0.030326  0.939692  0.893557   0.907933
# cv_svd_adasyn     0.634134    0.054128  0.926786  0.876577   0.846727
# tfidf_adasyn      1.543348    0.027635  0.944628  0.905224   0.912161
# tfidf_svd_adasyn  0.624815    0.061283  0.934732  0.878411   0.918302
#
#                     recall
# cv_smote          0.864426
# cv_svd_smote      0.902672
# tfidf_smote       0.903008
# tfidf_svd_smote   0.858660
# cv_adasyn         0.882805
# cv_svd_adasyn     0.910059
# tfidf_adasyn      0.899192
# tfidf_svd_adasyn  0.842699

# %% [markdown]
# - choosing the best model overall

# %%
__models = {}

# %%
__models["cv"] = create_model(
    SGDClassifier(**models["cv"]["estimator"].best_params_,loss="log_loss"),
    CountVectorizer(),
    with_svd=False,
    resampler=None
)

# %%
__models["cv_svd"] = create_model(
    SGDClassifier(**models["cv_svd"]["estimator"].best_params_,loss="log_loss"),
    CountVectorizer(),
    with_svd=True,
    resampler=None
)

# %%
__models["tfidf"] = create_model(
    SGDClassifier(**models["tfidf"]["estimator"].best_params_,loss="log_loss"),
    CountVectorizer(),
    with_svd=True,
    resampler=None
)

# %%
__models["tfidf_svd"] = create_model(
    SGDClassifier(**models["tfidf_svd"]["estimator"].best_params_,loss="log_loss"),
    CountVectorizer(),
    with_svd=True,
    resampler=None
)

# %%
__models["with_oversampling"] = _models[evaluation_df.index[evaluation_df["f1_score"].argmax()]]

# %%
evaluation_df = evaluate_cv(__models,scoring,cv=KFold(n_splits=5, shuffle=True),X=X, y=y)

# %%
evaluation_df
# Out:
#                    fit_time  score_time  accuracy  f1_score  precision  \
# cv                 0.410599    0.024542  0.907009  0.819674   0.922455
# cv_svd             0.988770    0.037401  0.930742  0.887524   0.834392
# tfidf              0.999447    0.037407  0.921850  0.873030   0.821693
# tfidf_svd          1.013939    0.037433  0.922841  0.874014   0.824758
# with_oversampling  1.545952    0.027103  0.936707  0.890522   0.880400
#
#                      recall
# cv                 0.738126
# cv_svd             0.948252
# tfidf              0.934193
# tfidf_svd          0.931623
# with_oversampling  0.903999

# %% [markdown]
# <div id="conclusion" >
#     <h3>Conclusion</h3>
# </div>

# %% [markdown]
# - After trying several feature extraction and balancing techniques the best model the one with:
#     - Tfidf as its feature extraction technique.
#     - with dimentiality reduction.
#     - oversampling with SMOTE
#     - an f1 score of 0.89.

# %% [markdown]
# <div id="save_the_best_model" >
#     <h3>Save the best model</h3>
# </div>

# %%
dump(value=__models[evaluation_df.index[evaluation_df["f1_score"].argmax()]],filename=os.path.join("..","..","models","ssl","sgd.joblib"))
# Out:
# ['../../models/ssl/sgd.joblib']
